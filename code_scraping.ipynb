# %% [markdown]
# # Scraping DCG.media

# %%
### SCRAPING
import requests as rq
from bs4 import BeautifulSoup

### DATABASES
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

### VISUALISATION
#import plotly.express as px

### DIVERS
from tqdm import tqdm

### FORMAT
from datetime import datetime, timezone
import time
import json

# %% [markdown]
# ## Définition des variables

# %%
website = 'creer-une-entreprise'
abbr = 'cue'
tld = '.com'

# %%
page_number = 1
top_url = f'https://www.{website+tld}'
top_search_url = f'{top_url}/page/{page_number}/?s'

# %% [markdown]
# ## Définition des fonctions

# %% [markdown]
# ### Obtenir le nombre de pages de résultats de recherche

# %%
def get_max_page_results(top_search_url):
    r = rq.get(top_search_url)
    soup = BeautifulSoup(r.content)
    page_final = soup.find_all('a', class_ = 'page-numbers')
    return int(page_final[-2].text)
get_max_page_results(top_search_url)
# Out:
# 14

# %% [markdown]
# ### Obtenir la liste des pages de résultats de recherche

# %%
def get_all_results_pages(page_final):
    urls = []
    for i in range(page_final):
        i = f'{top_url}/page/{i+1}/?s'
        urls.append(i)
    return urls
get_all_results_pages(get_max_page_results(top_search_url))
# Out:
# ['https://www.creer-une-entreprise.com/page/1/?s',
#  'https://www.creer-une-entreprise.com/page/2/?s',
#  'https://www.creer-une-entreprise.com/page/3/?s',
#  'https://www.creer-une-entreprise.com/page/4/?s',
#  'https://www.creer-une-entreprise.com/page/5/?s',
#  'https://www.creer-une-entreprise.com/page/6/?s',
#  'https://www.creer-une-entreprise.com/page/7/?s',
#  'https://www.creer-une-entreprise.com/page/8/?s',
#  'https://www.creer-une-entreprise.com/page/9/?s',
#  'https://www.creer-une-entreprise.com/page/10/?s',
#  'https://www.creer-une-entreprise.com/page/11/?s',
#  'https://www.creer-une-entreprise.com/page/12/?s',
#  'https://www.creer-une-entreprise.com/page/13/?s',
#  'https://www.creer-une-entreprise.com/page/14/?s']

# %% [markdown]
# ### Obtenir tous les liens des articles sur une page de recherche

# %%
def get_articles_on_page(search_results):
    urls_articles = []
    s = rq.Session()
    for p in tqdm(search_results):
        r = s.get(p)
        soup = BeautifulSoup(r.content)
        articles = soup.find_all('h2', class_ = 'title')
        for article in articles:
            url = article.find('a', href=True)['href']
            urls_articles.append(url)
    return urls_articles

# %%
get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
# 100%|██████████| 14/14 [00:05<00:00,  2.63it/s]
# ['https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/air-france-intralignes-comment-acceder-et-gerer-vos-outils-professionnels/',
#  'https://www.creer-une-entreprise.com/zodio-rachete-par-alinea-a-lalinea-atoll-impact-sur-le-marche-local/',
#  'https://www.creer-une-entreprise.com/myprimobox-comment-optimiser-la-gestion-electronique-des-documents-en-entreprise/',
#  'https://www.creer-une-entreprise.com/limpact-du-logo-apple-sur-la-perception-de-la-marque/',
#  'https://www.creer-une-entreprise.com/zimbra-cd66-et-la-transformation-numerique-des-collectivites-locales/',
#  'https://www.creer-une-entreprise.com/alyamanager-solution-de-gestion-pour-les-professionnels/',
#  'https://www.creer-une-entreprise.com/developpement-dapplication-mobile-dualmedia-services-innovants-pour-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/ami-compta-votre-outil-comptable-simplifie/',
#  'https://www.creer-une-entreprise.com/emploi-a-domicile-en-mise-sous-pli-verite-sur-sa-fiabilite-et-risques-darnaque/',
#  'https://www.creer-une-entreprise.com/deux-categories-de-logiciels-malveillants-a-connaitre-pour-proteger-votre-pc/',
#  'https://www.creer-une-entreprise.com/rebecca-gleeson-decouvrez-la-biographie-de-lattachee-de-presse-qui-fait-des-miracles/',
#  'https://www.creer-une-entreprise.com/le-mbn-un-outil-numerique-au-service-de-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/4-conseils-pour-trouver-le-numero-dun-service-client/',
#  'https://www.creer-une-entreprise.com/coliship-entreprise-lespace-colissimo-entreprise/',
#  'https://www.creer-une-entreprise.com/addviseo-connexion-a-son-compte-de-projet-professionnel/',
#  'https://www.creer-une-entreprise.com/quel-est-le-plafond-pour-un-couple-pour-toucher-la-prime-dactivite/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-3-attributs-du-triangle-dor-du-positionnement/',
#  'https://www.creer-une-entreprise.com/le-role-discret-de-po-dans-la-validation-des-documents-officiels/',
#  'https://www.creer-une-entreprise.com/les-enjeux-majeurs-de-la-securite-au-travail-aujourdhui/',
#  'https://www.creer-une-entreprise.com/les-services-les-plus-importants-offerts-par-une-entreprise-de-securite/',
#  'https://www.creer-une-entreprise.com/reinventer-le-transport-avec-la-palette-europe/',
#  'https://www.creer-une-entreprise.com/comment-optimiser-votre-recherche-demploi-dans-le-secteur-entrepreneurial-a-bayonne/',
#  'https://www.creer-une-entreprise.com/un-site-internet-est-il-indispensable-des-la-creation-de-son-entreprise/',
#  'https://www.creer-une-entreprise.com/les-avantages-dun-ecran-interactif-en-entreprise-pour-la-collaboration-et-la-productivite/',
#  'https://www.creer-une-entreprise.com/comment-optimiser-la-logistique-de-votre-entreprise-des-sa-creation/',
#  'https://www.creer-une-entreprise.com/comprendre-le-mecanisme-de-versement-du-dividende-en-sasu-astuces-et-conseils/',
#  'https://www.creer-une-entreprise.com/a-quel-gafam-appartient-linkedin-explorez-son-appartenance/',
#  'https://www.creer-une-entreprise.com/guide-complet-de-lassurance-professionnelle-pour-estheticienne/',
#  'https://www.creer-une-entreprise.com/mandat-ad-litem-choisir-un-expert-juridique-pour-votre-representation-2/',
#  'https://www.creer-une-entreprise.com/slow-movers-en-gestion-de-stock-comprendre-et-gerer-les-invendus-2/',
#  'https://www.creer-une-entreprise.com/comprendre-les-inducteurs-de-cout-definition-et-impact-sur-la-gestion/',
#  'https://www.creer-une-entreprise.com/decouvrir-les-opportunites-professionnelles-en-france-des-pistes-a-explorer/',
#  'https://www.creer-une-entreprise.com/comment-choisir-lemplacement-ideal-pour-un-distributeur-automatique-de-pizzas/',
#  'https://www.creer-une-entreprise.com/la-rse-un-levier-essentiel-pour-limage-de-marque-des-entreprises/',
#  'https://www.creer-une-entreprise.com/comment-fusionner-whatsapp-et-whatsapp-business/',
#  'https://www.creer-une-entreprise.com/credit-agricole-normandie-seine-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.creer-une-entreprise.com/la-caracterisation-dune-entreprise-a-travers-sa-culture/',
#  'https://www.creer-une-entreprise.com/business-model-canvas-comment-lutiliser-pour-developper-votre-activite/',
#  'https://www.creer-une-entreprise.com/comment-acheter-des-obligations-detat/',
#  'https://www.creer-une-entreprise.com/comment-creer-une-micro-entreprise-urssaf/',
#  'https://www.creer-une-entreprise.com/comment-verifier-lauthenticite-dun-bulletin-de-salaire/',
#  'https://www.creer-une-entreprise.com/quelles-sont-les-indemnites-de-licenciement/',
#  'https://www.creer-une-entreprise.com/limportance-de-la-gestion-des-risques-dans-lindustrie-de-process-et-des-infrastructures/',
#  'https://www.creer-une-entreprise.com/quel-effet-des-nouvelles-dates-de-paye-sur-la-remuneration-des-enseignants/',
#  'https://www.creer-une-entreprise.com/dates-de-salaire-de-leducation-nationale-comment-optimiser-ses-finances-personnelles/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/freelance-et-retraite-comment-bien-anticiper/',
#  'https://www.creer-une-entreprise.com/pourquoi-laugmentation-de-la-valeur-du-point-ccn-51-en-2024-metamorphose-t-elle-les-negociations-salariales/',
#  'https://www.creer-une-entreprise.com/swedishop-conseils-pour-bien-utiliser-cette-plateforme-e-commerce/',
#  'https://www.creer-une-entreprise.com/pourquoi-payer-pour-une-logiciel-de-comptabilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-sasu-definition-avantages-et-particularites/',
#  'https://www.creer-une-entreprise.com/calcul-de-la-valeur-ajoutee-comprendre-et-mesurer-son-impact-economique/',
#  'https://www.creer-une-entreprise.com/tout-savoir-sur-le-camion-rotisserie-moderne/',
#  'https://www.creer-une-entreprise.com/les-avantages-de-choisir-un-executive-mastere-pour-booster-sa-carriere/',
#  'https://www.creer-une-entreprise.com/vers-qui-se-tourner-pour-la-creation-dun-site-internet-a-dijon/',
#  'https://www.creer-une-entreprise.com/comment-choisir-une-assurance-pour-local-professionnel/',
#  'https://www.creer-une-entreprise.com/les-avantages-dune-experience-professionnelle-diversifiee/',
#  'https://www.creer-une-entreprise.com/analyse-du-marche-des-couches-comment-pampers-se-positionne-t-il/',
#  'https://www.creer-une-entreprise.com/chaussures-de-securite-respirantes-pourquoi-est-il-important-de-bien-respirer-au-travail/',
#  'https://www.creer-une-entreprise.com/comment-choisir-une-trottinette-electrique-pour-adulte/',
#  'https://www.creer-une-entreprise.com/modele-contrat-cdi/',
#  'https://www.creer-une-entreprise.com/quest-ce-que-le-swot/',
#  'https://www.creer-une-entreprise.com/cest-quoi-un-diplome-universitaire/',
#  'https://www.creer-une-entreprise.com/quelle-sont-les-outils-de-communication/',
#  'https://www.creer-une-entreprise.com/comment-on-peut-faire-un-questionnaire/',
#  'https://www.creer-une-entreprise.com/cest-quoi-le-micro-bic/',
#  'https://www.creer-une-entreprise.com/banques-en-ligne-et-entrepreneurs-tour-dhorizon-des-promotions-dediees/',
#  'https://www.creer-une-entreprise.com/maximisez-lexperience-de-loisirs-en-ligne-pour-vos-salaries/',
#  'https://www.creer-une-entreprise.com/impression-a-la-demande-3-choses-essentielles-a-savoir-a-propos-de-cette-revolution/',
#  'https://www.creer-une-entreprise.com/pourquoi-former-vos-equipes-a-lexploitation-des-systemes-de-securite-incendie/',
#  'https://www.creer-une-entreprise.com/outil-progeliance-les-solutions-innovantes-pour-la-gestion-dentreprise/',
#  'https://www.creer-une-entreprise.com/quest-ce-quun-rack-de-stockage/',
#  'https://www.creer-une-entreprise.com/lessence-juridique-du-lien-de-subordination-en-droit-du-travail/',
#  'https://www.creer-une-entreprise.com/eviter-les-ecueils-courants-sur-5euros-com-pour-doper-votre-business/',
#  'https://www.creer-une-entreprise.com/les-etapes-pour-se-lancer-dans-le-metier-de-cueilleur-de-fruits/',
#  'https://www.creer-une-entreprise.com/comment-trouver-un-grossiste-en-cigarette-electronique-pour-particulier-pres-de-chez-vous/',
#  'https://www.creer-une-entreprise.com/les-devoirs-et-droits-des-salaries-en-cas-de-cessation-dactivite-de-lentreprise/',
#  'https://www.creer-une-entreprise.com/quest-ce-quun-opco/',
#  'https://www.creer-une-entreprise.com/agents-de-securite-ssiap-equipez-vous-pour-une-protection-complete/',
#  'https://www.creer-une-entreprise.com/educateur-specialise-salaire-2021-et-perspectives-de-carriere/',
#  'https://www.creer-une-entreprise.com/quelle-difference-entre-marketing-digital-et-communication-digitale/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-types-de-motivation/',
#  'https://www.creer-une-entreprise.com/maximiser-votre-recherche-demploi-avec-une-agence-dinterim-a-reims-conseils-et-astuces/',
#  'https://www.creer-une-entreprise.com/un-guide-pour-devenir-un-joueur-de-haut-niveau-dans-brawl-stars/',
#  'https://www.creer-une-entreprise.com/optimiser-lefficacite-logistique-de-votre-entreprise-focus-sur-des-metiers-cles/',
#  'https://www.creer-une-entreprise.com/agence-lutie-pourquoi-confier-vos-campagnes-google-ads-a-des-experts/',
#  'https://www.creer-une-entreprise.com/guide-pour-choisir-le-format-ideal-pour-vos-videos-publicitaires/',
#  'https://www.creer-une-entreprise.com/comment-les-logiciels-facilitent-ils-la-facturation-des-prestations-a-domicile/',
#  'https://www.creer-une-entreprise.com/optimisez-votre-tresorerie-avec-une-societe-daffacturage-avantages-et-inconvenients/',
#  'https://www.creer-une-entreprise.com/logos-leroy-merlin-evolution-et-histoire-de-la-marque/',
#  'https://www.creer-une-entreprise.com/agri-affaire-solutions-innovantes-pour-une-agriculture-durable/',
#  'https://www.creer-une-entreprise.com/eveillez-vos-talents-culinaires-comment-demarrer-une-patisserie-rentable/',
#  'https://www.creer-une-entreprise.com/pourquoi-utiliser-des-signaletiques-publicitaires-lors-de-vos-salons-et-autres-evenements-dentreprise/',
#  'https://www.creer-une-entreprise.com/caracterisation-dune-entreprise-les-facteurs-cles-a-analyser/',
#  'https://www.creer-une-entreprise.com/mutuelle-hcr-pour-les-professionnels-de-lhotellerie-des-cafes-et-de-la-restauration/',
#  'https://www.creer-une-entreprise.com/quest-ce-quun-contrat-de-travail-permanent/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/quest-ce-quune-sarl/',
#  'https://www.creer-une-entreprise.com/tout-savoir-sur-le-mapping-concurrentiel/',
#  'https://www.creer-une-entreprise.com/realiser-la-creation-dune-sci/',
#  'https://www.creer-une-entreprise.com/comment-est-remunere-un-influenceur/',
#  'https://www.creer-une-entreprise.com/quel-master-pour-devenir-commissaire-de-police/',
#  'https://www.creer-une-entreprise.com/quelle-est-la-difference-entre-le-e-commerce-et-le-e-business/',
#  'https://www.creer-une-entreprise.com/comment-passer-de-lindivision-a-la-sci/',
#  'https://www.creer-une-entreprise.com/comment-favoriser-la-collaboration-pour-ameliorer-la-qualite-de-vie-au-travail/',
#  'https://www.creer-une-entreprise.com/bodywarmers-personnalises-faut-il-opter-pour-la-broderie-la-serigraphie-ou-le-transfert/',
#  'https://www.creer-une-entreprise.com/alignement-et-impact-limportance-essentielle-des-valeurs-dentreprise/',
#  'https://www.creer-une-entreprise.com/solutions-pratiques-pour-imprimantes-focus-sur-les-bobines-thermiques-adhesives/',
#  'https://www.creer-une-entreprise.com/optimisez-vos-processus-avec-openpm-guide-pour-les-neophytes/',
#  'https://www.creer-une-entreprise.com/maximiser-vos-ventes-avec-cash-converters-a-lattes-conseils-et-astuces/',
#  'https://www.creer-une-entreprise.com/envoyer-un-colis-aux-etats-unis-tout-ce-que-vous-devez-savoir/',
#  'https://www.creer-une-entreprise.com/comment-un-cabinet-de-recrutement-web-peut-reduire-votre-temps-de-recrutement/',
#  'https://www.creer-une-entreprise.com/b2pweb-mobile-une-bourse-de-fret-a-portee-de-main/',
#  'https://www.creer-une-entreprise.com/comprendre-le-be-to-see-definition-et-strategies-marketing-efficaces/',
#  'https://www.creer-une-entreprise.com/ouvriers-quels-equipements-choisir-pour-votre-securite-et-confort/',
#  'https://www.creer-une-entreprise.com/sylae-asp-le-portail-employeur-pour-contrats-aides/',
#  'https://www.creer-une-entreprise.com/comment-calculer-le-nombre-daction-dune-entreprise/',
#  'https://www.creer-une-entreprise.com/les-entreprises-a-finalite-societale-moteurs-dinnovation-sociale/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-criteres-essentiels-pour-choisir-un-avocat-fiscaliste-a-paris/',
#  'https://www.creer-une-entreprise.com/les-avantages-dun-expert-comptable-pour-une-start-up/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-points-a-savoir-sur-linfogerance-ovh/',
#  'https://www.creer-une-entreprise.com/caisse-depargne-dauvergne-et-du-limousin-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.creer-une-entreprise.com/resiliation-resilier-son-contrat-electricite-chez-ekwateur/',
#  'https://www.creer-une-entreprise.com/ou-sont-fabriques-les-pneus-michelin-tout-savoir-sur-leur-production/',
#  'https://www.creer-une-entreprise.com/comment-choisir-un-presentoir-de-sol-efficace/',
#  'https://www.creer-une-entreprise.com/salon-professionnel-pourquoi-miser-sur-la-force-de-conversion-des-objets-publicitaires/',
#  'https://www.creer-une-entreprise.com/les-avantages-dune-plv-de-sol-pour-booster-votre-visibilite-en-magasin/',
#  'https://www.creer-une-entreprise.com/comment-booster-la-rentabilite-dun-reseau-de-franchises/',
#  'https://www.creer-une-entreprise.com/les-6-meilleurs-conseils-pour-ameliorer-votre-classement-dans-rainbow-six-siege/',
#  'https://www.creer-une-entreprise.com/retail-en-commerce-comprendre-la-definition-et-les-enjeux-essentiels/',
#  'https://www.creer-une-entreprise.com/entreprise-le-tampon-encreur-la-signature-professionnelle-qui-fait-la-difference/',
#  'https://www.creer-une-entreprise.com/les-fonctionnalites-meconnues-dexcel-pour-une-simulation-precise-de-portage-salarial/',
#  'https://www.creer-une-entreprise.com/les-coffrets-cadeaux-un-moyen-incontournable-de-fideliser-clients-salaries-et-partenaires/',
#  'https://www.creer-une-entreprise.com/3-cles-pour-reussir-a-scaler-son-business-quels-points-fondamentaux-considerer/',
#  'https://www.creer-une-entreprise.com/comment-comptabiliser-des-dividendes-un-guide-pour-les-entreprises/',
#  'https://www.creer-une-entreprise.com/comment-ouvrir-une-entreprise-sasu/',
#  'https://www.creer-une-entreprise.com/comment-faire-un-planning-pour-le-personnel/',
#  'https://www.creer-une-entreprise.com/cegidlife-tout-savoir-sur-cette-solution-rh/',
#  'https://www.creer-une-entreprise.com/pourquoi-il-est-indispensable-davoir-une-image-alignee-avec-son-positionnement/',
#  'https://www.creer-une-entreprise.com/a-lattention-de-maitre-lart-de-la-communication-epistolaire-avec-un-avocat/',
#  'https://www.creer-une-entreprise.com/ruban-adhesif-pour-emballage-quelle-resistance-choisir/',
#  'https://www.creer-une-entreprise.com/comment-maximiser-les-ressources-de-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/comment-ameliorer-lefficacite-de-la-gestion-des-documents-en-entreprise/',
#  'https://www.creer-une-entreprise.com/comment-choisir-acheter-et-entretenir-le-costume-daffaire-ideal/',
#  'https://www.creer-une-entreprise.com/a-b-testing-cest-quoi-et-comment-lappliquer/',
#  'https://www.creer-une-entreprise.com/les-avantages-fiscaux-du-portage-salarial-a-lille-les-cles-dune-simulation-reussie/',
#  'https://www.creer-une-entreprise.com/comment-porter-des-sneakers-avec-une-tenue-de-bureau-chic/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/comment-les-entreprises-peuvent-elles-se-conformer-aux-exigences-environnementales-grace-a-laudit-energetique/',
#  'https://www.creer-une-entreprise.com/tertiarisation-de-la-population-active-impact-et-evolution-du-secteur-tertiaire/',
#  'https://www.creer-une-entreprise.com/slow-movers-en-gestion-de-stock-comprendre-et-gerer-les-invendus/',
#  'https://www.creer-une-entreprise.com/la-sarl-en-suisse-lentreprise-ideale-pour-se-lancer-en-suisse/',
#  'https://www.creer-une-entreprise.com/bien-choisir-son-food-truck/',
#  'https://www.creer-une-entreprise.com/comment-travailler-a-la-poste-aujourdhui-nos-conseils/',
#  'https://www.creer-une-entreprise.com/quest-ce-que-lautre-stockage-sur-mac-et-comment-leffacer/',
#  'https://www.creer-une-entreprise.com/pourquoi-investir-dans-une-franchise-de-laverie-peut-etre-une-opportunite-rentable/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-avantages-dun-contrat-a-duree-indeterminee/',
#  'https://www.creer-une-entreprise.com/comment-optimiser-vos-campagnes-de-mailing-sms-pour-atteindre-vos-objectifs/',
#  'https://www.creer-une-entreprise.com/les-differents-types-dinvestissements-en-tant-quinvestisseur/',
#  'https://www.creer-une-entreprise.com/auto-entrepreneurs-du-btp-comment-anticiper-les-couts-de-protection-professionnelle/',
#  'https://www.creer-une-entreprise.com/selfservice-keolis-comment-acceder-aux-informations-des-employes/',
#  'https://www.creer-une-entreprise.com/optimisation-des-jours-ouvres-2024-pour-les-professionnels/',
#  'https://www.creer-une-entreprise.com/comparer-les-jours-ouvres-2024-en-europe-focus-sur-les-principales-disparites/',
#  'https://www.creer-une-entreprise.com/comment-bien-preparer-la-vente-de-votre-magasin-doptique/',
#  'https://www.creer-une-entreprise.com/petit-espace-et-efficacite-maximale-comment-amenager-vos-bureaux-professionnels/',
#  'https://www.creer-une-entreprise.com/les-outils-indispensables-pour-une-gestion-de-projet-efficace-en-entreprise/',
#  'https://www.creer-une-entreprise.com/pourquoi-faire-appel-aux-services-de-onliz-pour-equiper-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/comment-choisir-une-banque-en-ligne-pour-son-entreprise/',
#  'https://www.creer-une-entreprise.com/mail-ac-montpellier-optimiser-votre-utilisation-pour-une-meilleure-productivite/',
#  'https://www.creer-une-entreprise.com/quelle-est-limportance-dinstaller-une-main-courante-descalier/',
#  'https://www.creer-une-entreprise.com/optimisez-la-gestion-de-votre-entreprise-avec-excel/',
#  'https://www.creer-une-entreprise.com/strategies-pour-optimiser-la-gestion-interne-de-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/optimiser-la-gestion-de-vos-courriels-a-nancy-metz/',
#  'https://www.creer-une-entreprise.com/pacte-dutreil-une-opportunite-pour-securiser-la-transmission-de-votre-patrimoine-professionnel/',
#  'https://www.creer-une-entreprise.com/integration-des-solutions-demargement-en-ligne-pour-son-entreprise/',
#  'https://www.creer-une-entreprise.com/les-erreurs-frequentes-a-eviter-lors-de-lajout-dun-credit-photo/',
#  'https://www.creer-une-entreprise.com/les-maisons-dedition-et-lessor-du-livre-numerique/',
#  'https://www.creer-une-entreprise.com/limpact-de-smart-rh-sur-la-transformation-numerique-des-entreprises/',
#  'https://www.creer-une-entreprise.com/consultation-chez-un-avocat-a-quel-cout-vous-attendre/',
#  'https://www.creer-une-entreprise.com/parking-sous-sol-comment-les-isoler/',
#  'https://www.creer-une-entreprise.com/comment-choisir-la-bonne-societe-fiduciaire-en-suisse/',
#  'https://www.creer-une-entreprise.com/assurance-allianz-professionnelle-les-assurances-entreprises/',
#  'https://www.creer-une-entreprise.com/icarus-media-digital-lancement-et-perennisation-dentreprises/',
#  'https://www.creer-une-entreprise.com/quelle-est-la-difference-entre-une-banque-et-un-etablissement-financier/',
#  'https://www.creer-une-entreprise.com/quelle-filiere-choisir-pour-devenir-comptable/',
#  'https://www.creer-une-entreprise.com/les-solutions-de-sante-essentielles-pour-les-entrepreneurs-proteger-son-entreprise-et-soi-meme/',
#  'https://www.creer-une-entreprise.com/comment-allier-elegance-et-marketing-avec-des-sacs-de-luxe-pour-votre-marque/',
#  'https://www.creer-une-entreprise.com/optimiser-la-performance-de-son-equipe-avec-les-meilleures-strategies-de-management/',
#  'https://www.creer-une-entreprise.com/devenez-independant-en-vous-formant-en-ligne/',
#  'https://www.creer-une-entreprise.com/laurent-marchand-les-avis-des-participants-sur-son-accompagnement-a-la-reussite-autant-professionnelle-que-personnelle/',
#  'https://www.creer-une-entreprise.com/guide-pratique-pour-se-connecter-au-portail-cgos-en-toute-quietude/',
#  'https://www.creer-une-entreprise.com/comment-bien-amenager-un-food-truck-et-optimiser-son-espace/',
#  'https://www.creer-une-entreprise.com/3-cles-pour-reussir-a-scaler-son-business-quels-points-fondamentaux-considerer-2/',
#  'https://www.creer-une-entreprise.com/comment-connecter-et-deconnecter-mailchimp-et-canva/',
#  'https://www.creer-une-entreprise.com/quel-type-dentreprise-faut-il-monter-pour-gagner-de-largent-en-2022/',
#  'https://www.creer-une-entreprise.com/les-avantages-commerciaux-de-la-location-de-voiture-pour-les-entrepreneurs-en-deplacement/',
#  'https://www.creer-une-entreprise.com/la-personnalite-juridique-definition-et-implications-pour-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/comment-mettre-en-place-un-acces-internet-pour-ses-clients/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/quel-est-lapport-des-panneaux-danger-en-entreprise/',
#  'https://www.creer-une-entreprise.com/comment-rompre-un-contrat-alternance/',
#  'https://www.creer-une-entreprise.com/comment-obtenir-le-numero-gratuit-dun-service-client/',
#  'https://www.creer-une-entreprise.com/les-obligations-legales-a-connaitre-pour-exercer-en-abc-portage-salarial/',
#  'https://www.creer-une-entreprise.com/comment-calculer-son-salaire-en-portage-salarial/',
#  'https://www.creer-une-entreprise.com/quelle-est-lutilite-de-lassistance-juridique-cse/',
#  'https://www.creer-une-entreprise.com/comment-une-machine-a-cafe-automatique-peut-elle-profiter-a-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/devenir-freelance-en-2023-4-conseils-pour-se-lancer/',
#  'https://www.creer-une-entreprise.com/les-5-principaux-avantages-dinvestir-dans-une-franchise-de-laverie-automatique/',
#  'https://www.creer-une-entreprise.com/tampons-personnalises-pour-cartes-de-fidelite/',
#  'https://www.creer-une-entreprise.com/les-leaders-du-luxe-quel-salaire-pour-un-pdg/',
#  'https://www.creer-une-entreprise.com/combien-de-jours-travailles-par-an-pour-les-professions-liberales/',
#  'https://www.creer-une-entreprise.com/comment-optimiser-la-gestion-des-flux-dans-les-batiments-commerciaux/',
#  'https://www.creer-une-entreprise.com/renforcer-la-cohesion-dequipe-les-avantages-inestimables-dune-formation-en-team-building/',
#  'https://www.creer-une-entreprise.com/4-raisons-pour-lesquelles-les-garde-corps-sont-primordiaux-pour-la-securite-dun-site-de-construction/',
#  'https://www.creer-une-entreprise.com/les-conseils-pour-bien-choisir-les-equipements-de-votre-cabinet-veterinaire/',
#  'https://www.creer-une-entreprise.com/reinventez-votre-facon-de-travailler-avec-des-espaces-de-coworking-innovants/',
#  'https://www.creer-une-entreprise.com/vaisselle-jetable-quelle-solution-pour-chaque-occasion/',
#  'https://www.creer-une-entreprise.com/linnovation-au-coeur-des-entreprises-espagnoles/',
#  'https://www.creer-une-entreprise.com/se-lancer-en-tant-que-consultant-freelance-les-avantages-du-portage-salarial/',
#  'https://www.creer-une-entreprise.com/comment-bien-choisir-une-cabine-acoustique/',
#  'https://www.creer-une-entreprise.com/pourquoi-choisir-un-avocat-fiscaliste-international/',
#  'https://www.creer-une-entreprise.com/limportance-de-la-qualite-des-donnees-dans-lachat-de-fichier-dentreprises/',
#  'https://www.creer-une-entreprise.com/pourquoi-organiser-un-seminaire-a-lyon/',
#  'https://www.creer-une-entreprise.com/comprendre-la-cooperativite-definition-principes-et-applications/',
#  'https://www.creer-une-entreprise.com/top-10-des-actions-en-2022/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-points-forts-des-banques-en-ligne/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-meilleurs-logiciels-de-comptabilite-et-gestion-en-2024/',
#  'https://www.creer-une-entreprise.com/exploration-des-statistiques-comprendre-le-profil-des-auto-entrepreneurs-selon-linsee/',
#  'https://www.creer-une-entreprise.com/definition-marketing-du-conatif-comprendre-limpact-sur-la-consommation/',
#  'https://www.creer-une-entreprise.com/goodies-et-cadeaux-daffaires-a-quoi-servent-ils/',
#  'https://www.creer-une-entreprise.com/ago-vs-age-comprendre-les-differences-essentielles-pour-les-assemblees/',
#  'https://www.creer-une-entreprise.com/calcul-solde-de-tout-compte-cdi-methode-et-etapes-cles/',
#  'https://www.creer-une-entreprise.com/le-role-essentiel-du-negociant-en-bois-dans-la-distribution-de-materiaux/',
#  'https://www.creer-une-entreprise.com/que-signifie-cdd-tout-ce-que-vous-devez-savoir-sur-ce-type-de-contrat-de-travail/',
#  'https://www.creer-une-entreprise.com/earn-out-avantage-et-inconvenient-de-cette-clause/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-objectifs-dun-plan-de-communication/',
#  'https://www.creer-une-entreprise.com/comment-rendre-actif-un-lien-internet/',
#  'https://www.creer-une-entreprise.com/les-roles-cles-dans-le-monde-de-la-finance-dentreprise-a-paris/',
#  'https://www.creer-une-entreprise.com/quel-est-linteret-pour-une-entreprise-devaluer-son-bilan-carbone/',
#  'https://www.creer-une-entreprise.com/la-combinaison-de-travail-un-vetement-indispensable-et-polyvalent/',
#  'https://www.creer-une-entreprise.com/les-competences-indispensables-pour-devenir-un-expert-en-comptabilite/',
#  'https://www.creer-une-entreprise.com/guide-complet-pour-la-creation-dune-eurl-en-france/',
#  'https://www.creer-une-entreprise.com/domiciliation-dentreprise-paris-12-charenton/',
#  'https://www.creer-une-entreprise.com/pourquoi-une-enseigne-est-un-atout-majeur-pour-la-notoriete-de-son-entreprise/',
#  'https://www.creer-une-entreprise.com/comment-creer-un-blog-professionnel/',
#  'https://www.creer-une-entreprise.com/lessor-du-travailleur-independant-sur-le-marche-de-lemploi/',
#  'https://www.creer-une-entreprise.com/en-quoi-la-cobotique-peut-elle-jouer-sur-la-production-des-pme/',
#  'https://www.creer-une-entreprise.com/les-indicateurs-cles-a-analyser-dans-une-simulation-de-portage-salarial-realisee-avec-excel/',
#  'https://www.creer-une-entreprise.com/comment-choisir-le-meilleur-endroit-pour-imprimer-des-documents-nos-criteres/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/presentation-et-solutions-manageo/',
#  'https://www.creer-une-entreprise.com/comment-faire-pour-ne-pas-payer-le-rsi/',
#  'https://www.creer-une-entreprise.com/que-faire-pour-le-bien-etre-de-ses-salaries/',
#  'https://www.creer-une-entreprise.com/les-roles-cles-dun-expert-comptable-lors-de-la-creation-dune-entreprise/',
#  'https://www.creer-une-entreprise.com/comment-choisir-efficacement-son-systeme-de-detection-dintrusion-pour-securiser-son-entreprise/',
#  'https://www.creer-une-entreprise.com/comprendre-et-remplir-efficacement-le-formulaire-fcmb-conseils-et-astuces/',
#  'https://www.creer-une-entreprise.com/correspondance-soignee-bien-employer-dans-lattente-de-votre-retour/',
#  'https://www.creer-une-entreprise.com/les-quatre-roles-du-cse-en-matiere-de-sante-et-de-securite/',
#  'https://www.creer-une-entreprise.com/le-cnas-sud-est-pilier-de-laction-sociale-pour-les-collectivites/',
#  'https://www.creer-une-entreprise.com/ab-test-ameliorer-son-taux-de-conversion-sur-site/',
#  'https://www.creer-une-entreprise.com/comprendre-ce-quest-une-societe-de-portage/',
#  'https://www.creer-une-entreprise.com/le-portage-salarial-une-solution-pour-les-independants/',
#  'https://www.creer-une-entreprise.com/prevention-et-gestion-des-nuisibles-dans-les-espaces-professionnels/',
#  'https://www.creer-une-entreprise.com/faut-il-vraiment-un-site-web-pour-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/partylite-my-business-gestion-de-votre-activite/',
#  'https://www.creer-une-entreprise.com/la-facturation-simplifiee-pour-les-pros-du-batiment/',
#  'https://www.creer-une-entreprise.com/quel-budget-prevoir-pour-les-emballages-alimentaires-en-restauration/',
#  'https://www.creer-une-entreprise.com/myarkevia-revolutionnez-votre-approche-de-la-transformation-numerique/',
#  'https://www.creer-une-entreprise.com/devenez-un-investisseur-avise-avec-spynance-notre-test-complet/',
#  'https://www.creer-une-entreprise.com/les-avantages-insoupconnes-des-tampons-encreurs-pour-la-gestion-administrative/',
#  'https://www.creer-une-entreprise.com/comment-lancer-son-business-dauto-entrepreneur-dans-le-secteur-du-menage-etapes-cles-et-astuces-pratiques/',
#  'https://www.creer-une-entreprise.com/plateforme-logistique-definition-fonctionnement-et-exemples-pertinents/',
#  'https://www.creer-une-entreprise.com/enseigne-lumineuse-personnalisee-pour-lexterieur-comment-creer-une-identite-visuelle-unique-pour-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/les-differences-entre-les-franchises-donuts-en-france/',
#  'https://www.creer-une-entreprise.com/les-differentes-fonctions-dun-agent-de-call-center-et-leur-importance-pour-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/les-bonnes-pratiques-a-adopter-pour-reussir-son-tremplin-numerique-en-seo/',
#  'https://www.creer-une-entreprise.com/implantez-votre-entreprise-en-andorre-un-guide-pratique/',
#  'https://www.creer-une-entreprise.com/comment-programmer-ses-publications-sur-instagram/',
#  'https://www.creer-une-entreprise.com/guide-du-debutant-pour-se-lancer-sur-amazon-fba/',
#  'https://www.creer-une-entreprise.com/comment-creer-un-blog-gratuitement-et-facilement-sur-google/',
#  'https://www.creer-une-entreprise.com/quel-est-le-but-dune-entreprise-publique/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-moyens-dont-lentreprise-a-besoin-pour-fonctionner/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-actions-marketing/',
#  'https://www.creer-une-entreprise.com/linteret-dinvestir-dans-les-meilleurs-logiciels-de-planification-de-projet/',
#  'https://www.creer-une-entreprise.com/comment-declarer-ses-revenus-auto-entrepreneur-impots-2021/',
#  'https://www.creer-une-entreprise.com/choisir-la-meilleure-banque-pro-pour-votre-startup/',
#  'https://www.creer-une-entreprise.com/ouvrir-un-parc-de-loisirs-les-elements-a-prendre-en-compte/',
#  'https://www.creer-une-entreprise.com/simplifier-la-gestion-de-la-paie-de-votre-entreprise-avec-une-solution-en-ligne/',
#  'https://www.creer-une-entreprise.com/comment-optimiser-la-gestion-de-vos-fiches-de-paie-en-ligne/',
#  'https://www.creer-une-entreprise.com/le-role-des-agences-dinterim-dans-la-dynamisation-du-marche-de-lemploi-en-bretagne-et-normandie/',
#  'https://www.creer-une-entreprise.com/comment-atteindre-vos-objectifs-de-communication-grace-a-lassertivite-5-principes-cles/',
#  'https://www.creer-une-entreprise.com/comment-choisir-la-meilleure-agence-de-branding/',
#  'https://www.creer-une-entreprise.com/7-strategies-pour-ameliorer-le-developpement-dune-entreprise/',
#  'https://www.creer-une-entreprise.com/les-raisons-pour-lesquelles-les-entreprises-sappuient-sur-des-traiteurs-pour-leurs-evenements/',
#  'https://www.creer-une-entreprise.com/selectionnez-le-mobilier-ideal-pour-votre-cuisine-professionnelle/',
#  'https://www.creer-une-entreprise.com/objets-publicitaires-francais-tendances-et-choix-ecoresponsables/',
#  'https://www.creer-une-entreprise.com/les-obligations-legales-liees-a-la-publication-dune-annonce-de-dissolution/',
#  'https://www.creer-une-entreprise.com/3-conseils-pour-renforcer-vos-equipes-de-vente/',
#  'https://www.creer-une-entreprise.com/pourquoi-choisir-une-entreprise-de-deconstruction-pour-votre-projet/',
#  'https://www.creer-une-entreprise.com/revue-de-projet-efficace-etapes-cles-et-meilleures-pratiques-2/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/les-avantages-dun-logiciel-de-phoning-pour-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/la-duree-legale-du-travail-journalier-dans-le-monde/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-objectifs-du-bilan-social/',
#  'https://www.creer-une-entreprise.com/comment-reussir-a-fideliser-ses-clients-grace-au-digital/',
#  'https://www.creer-une-entreprise.com/travaux-publics-types-et-caracteristiques-essentiels-pour-vos-projets/',
#  'https://www.creer-une-entreprise.com/droit-du-travail-comprendre-les-regles-pour-le-trajet-domicile-travail/',
#  'https://www.creer-une-entreprise.com/les-principales-fonctions-dun-manager/',
#  'https://www.creer-une-entreprise.com/vaut-il-mieux-creer-une-entreprise-de-zero-ou-racheter-une-entreprise-deja-en-place/',
#  'https://www.creer-une-entreprise.com/prise-dinitiative-en-entreprise-cle-du-succes-et-performance-accrue/',
#  'https://www.creer-une-entreprise.com/quelles-sont-les-etapes-de-creation-dune-eurl/',
#  'https://www.creer-une-entreprise.com/role-cle-des-entreprises-de-transport-dans-la-gestion-de-la-supply-chain/',
#  'https://www.creer-une-entreprise.com/les-tendances-en-matiere-disolation-en-polystyrene-expanse-dans-le-secteur-du-batiment/',
#  'https://www.creer-une-entreprise.com/cest-quoi-le-transport-international/',
#  'https://www.creer-une-entreprise.com/choisir-son-statut-pour-livreur-uber-eats-conseils-et-astuces/',
#  'https://www.creer-une-entreprise.com/les-avantages-dun-totem-dinterieur-pour-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/tpe-mobile-solution-pour-encaisser-des-paiements-en-mobilite/',
#  'https://www.creer-une-entreprise.com/entreprise-pourquoi-faire-un-audit-energetique-reglementaire/',
#  'https://www.creer-une-entreprise.com/puis-je-licencier-un-salarie-en-arret-maladie/',
#  'https://www.creer-une-entreprise.com/creer-une-entreprise-a-dubai-demarches-et-conseils-essentiels/',
#  'https://www.creer-une-entreprise.com/controle-urssaf-pour-micro-entrepreneurs-demarches-et-preparation/',
#  'https://www.creer-une-entreprise.com/abandon-de-poste-en-2023-comprendre-les-regles-et-consequences-juridiques/',
#  'https://www.creer-une-entreprise.com/livraison-de-colis-optez-pour-un-emballage-de-qualite/',
#  'https://www.creer-une-entreprise.com/choisir-le-meilleur-support-pour-la-prise-de-notes-a-lecole/',
#  'https://www.creer-une-entreprise.com/optimiser-la-gestion-des-ressources-humaines-strategies-efficaces-pour-booster-la-performance-de-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/mandat-ad-litem-choisir-un-expert-juridique-pour-votre-representation/',
#  'https://www.creer-une-entreprise.com/comment-creer-sa-politique-rh-dans-son-entreprise-en-2024/',
#  'https://www.creer-une-entreprise.com/pourquoi-choisir-une-agence-seo-pour-booster-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/designation-dun-dpo-quand-comment-et-pourquoi-nommer-un-delegue-a-la-protection-des-donnees/',
#  'https://www.creer-une-entreprise.com/cout-et-rentabilite-des-campagnes-google-ads-optimisez-vos-depenses/',
#  'https://www.creer-une-entreprise.com/pourquoi-investir-dans-des-parasols-pour-la-terrasse-de-votre-restaurant/',
#  'https://www.creer-une-entreprise.com/obligation-de-moyens-vs-de-resultat-comprendre-les-differences-essentielles/',
#  'https://www.creer-une-entreprise.com/differences-mission-et-vision-en-marketing-strategies-dentreprise-efficaces/',
#  'https://www.creer-une-entreprise.com/gestion-efficace-des-archives-dentreprise-comment-sy-prendre/',
#  'https://www.creer-une-entreprise.com/decouvrir-la-rochelle-vivre-travailler-et-sepanouir-dans-cette-ville-maritime/',
#  'https://www.creer-une-entreprise.com/les-outils-dautomation-des-allies-de-taille-pour-votre-business-2/',
#  'https://www.creer-une-entreprise.com/les-outils-dautomation-des-allies-de-taille-pour-votre-business/',
#  'https://www.creer-une-entreprise.com/avis-de-salaries-sur-employeurs-fonctionnement-et-impact-seo/',
#  'https://www.creer-une-entreprise.com/estimez-les-prix-dun-site-internet-avant-de-promouvoir-votre-marque/',
#  'https://www.creer-une-entreprise.com/metiers-de-nuit-a-haute-remuneration-top-des-emplois-lucratifs/',
#  'https://www.creer-une-entreprise.com/comment-maitriser-et-diminuer-le-cout-des-achats-de-classe-c/',
#  'https://www.creer-une-entreprise.com/la-technologie-de-securite-decodee-comment-fonctionne-une-alarme-anti-intrusion/',
#  'https://www.creer-une-entreprise.com/la-videosurveillance-un-outil-de-protection-essentiel-au-sein-des-entreprises/',
#  'https://www.creer-une-entreprise.com/la-veille-concurrentielle-au-service-de-la-performance-de-lentreprise/',
#  'https://www.creer-une-entreprise.com/creation-dentreprise-et-business-plan-faites-vous-aider/',
#  'https://www.creer-une-entreprise.com/quelles-sont-les-specificites-comptables-dune-holding/',
#  'https://www.creer-une-entreprise.com/revue-de-projet-efficace-etapes-cles-et-meilleures-pratiques/',
#  'https://www.creer-une-entreprise.com/5-idees-pour-lancer-votre-business-en-ligne-en-2024/',
#  'https://www.creer-une-entreprise.com/comment-se-demarquer-lors-du-choix-du-nom-de-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/modeles-de-lettre-reussir-toutes-vos-communications-avec-lettre-reco/',
#  'https://www.creer-une-entreprise.com/les-innovations-technologiques-au-service-des-nouvelles-entreprises-dans-leconomie-numerique/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/enveloppe-plastique-une-alternative-a-une-enveloppe-en-papier/',
#  'https://www.creer-une-entreprise.com/6-avantages-des-fenetres-en-pvc/',
#  'https://www.creer-une-entreprise.com/quand-faut-il-faire-appel-a-une-agence-de-referencement/',
#  'https://www.creer-une-entreprise.com/6-astuces-pour-reussir-le-packaging-dun-produit-cosmetique-de-marque/',
#  'https://www.creer-une-entreprise.com/comprendre-le-recrutement-predictif/',
#  'https://www.creer-une-entreprise.com/team-building-deauville-les-activites-a-faire-pour-vous-divertir-et-vous-relaxer/',
#  'https://www.creer-une-entreprise.com/pourquoi-collaborer-avec-un-referenceur-independant-est-la-cle-pour-optimiser-la-visibilite-en-ligne/',
#  'https://www.creer-une-entreprise.com/coaching-professionnel-a-paris-le-guide-complet/',
#  'https://www.creer-une-entreprise.com/appels-entrants-comment-assurer-une-bonne-gestion-des-appels/',
#  'https://www.creer-une-entreprise.com/la-gestion-du-stress-un-levier-pour-ameliorer-le-bien-etre-au-travail/',
#  'https://www.creer-une-entreprise.com/pourquoi-solliciter-laccompagnement-dun-cabinet-juridique/',
#  'https://www.creer-une-entreprise.com/comment-choisir-votre-fabricant-de-materiel-delevage/',
#  'https://www.creer-une-entreprise.com/les-avantages-de-la-fabrication-en-serie-des-equipements-industriels/',
#  'https://www.creer-une-entreprise.com/escape-games-a-rennes-une-experience-de-jeu-hors-du-commun/',
#  'https://www.creer-une-entreprise.com/la-sst-en-entreprise-comprendre-la-formation-necessaire/',
#  'https://www.creer-une-entreprise.com/comment-ameliorer-vos-gestes-et-postures-grace-a-des-formations-specialisees/',
#  'https://www.creer-une-entreprise.com/les-avantages-du-portage-salarial-pour-les-travailleurs-independants/',
#  'https://www.creer-une-entreprise.com/peut-on-creer-une-entreprise-en-etant-salarie-les-demarches-et-les-considerations-a-prendre-en-compte/',
#  'https://www.creer-une-entreprise.com/les-desavantages-du-portage-salarial-et-comment-les-surmonter/',
#  'https://www.creer-une-entreprise.com/lelevage-avicole-et-la-necessite-dun-materiel-adapte/',
#  'https://www.creer-une-entreprise.com/les-avantages-de-travailler-avec-une-agence-web-a-dijon/',
#  'https://www.creer-une-entreprise.com/comment-faire-face-a-la-pression-des-clients-et-des-collegues/',
#  'https://www.creer-une-entreprise.com/pourquoi-faire-appel-a-un-journaliste-animateur/',
#  'https://www.creer-une-entreprise.com/comment-ameliorer-la-visibilite-de-son-entreprise-sur-le-web/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-indicateurs-de-la-gestion-des-ressources-humaines/',
#  'https://www.creer-une-entreprise.com/les-effets-du-cbd-sur-la-sante-humaine/',
#  'https://www.creer-une-entreprise.com/les-raisons-pour-se-lancer-dans-lentrepreneuriat/',
#  'https://www.creer-une-entreprise.com/les-avantages-de-collaborer-avec-une-entreprise-de-prospection-specialisee/',
#  'https://www.creer-une-entreprise.com/une-agence-seo-soccupe-de-votre-visibilite/',
#  'https://www.creer-une-entreprise.com/ou-se-trouvent-les-meilleures-opportunites-demploi/',
#  'https://www.creer-une-entreprise.com/quelle-assurance-locale-dentreprise-choisir/',
#  'https://www.creer-une-entreprise.com/les-opportunites-offertes-par-les-etudes-superieures-en-informatique-et-multimedia/',
#  'https://www.creer-une-entreprise.com/le-role-cle-du-directeur-marketing-externalise-dans-votre-strategie-de-croissance/',
#  'https://www.creer-une-entreprise.com/limpact-positif-de-la-responsabilite-sociale-des-entreprises-dans-notre-societe/',
#  'https://www.creer-une-entreprise.com/les-perspectives-devolution-en-portage-salarial-dans-les-annees-a-venir/',
#  'https://www.creer-une-entreprise.com/franchise-pour-entrepreneurs-decryptage-des-avantages-et-des-inconvenients/',
# ...
#  'https://www.creer-une-entreprise.com/la-gestion-de-projet-en-entreprise-un-levier-pour-le-succes/',
#  'https://www.creer-une-entreprise.com/les-pieges-a-eviter-pour-reussir-son-marketing-dentreprise/',
#  'https://www.creer-une-entreprise.com/les-mesures-a-prendre-pour-proteger-vos-cartes-bancaires/',
#  'https://www.creer-une-entreprise.com/les-avantages-de-simuler-le-portage-salarial-avec-excel/',
#  'https://www.creer-une-entreprise.com/les-outils-incontournables-pour-la-gestion-efficace-dune-association/',
#  'https://www.creer-une-entreprise.com/les-fonctionnalites-essentielles-dun-logiciel-de-gestion-financiere/',
#  'https://www.creer-une-entreprise.com/les-cles-du-succes-en-marketing-international-exploiter-les-avantages-et-contourner-les-pieges-pour-les-entreprises/',
#  'https://www.creer-une-entreprise.com/proteger-efficacement-la-vie-privee-et-les-donnees-des-employes-en-entreprise/',
#  'https://www.creer-une-entreprise.com/le-pouvoir-dune-publicite-efficace-pour-votre-marque/',
#  'https://www.creer-une-entreprise.com/dematerialiser-les-factures-et-documents-dentreprise-comment-faire/',
#  'https://www.creer-une-entreprise.com/les-defis-du-suivi-en-entreprise-et-comment-les-surmonter/',
#  'https://www.creer-une-entreprise.com/les-avantages-des-logiciels-sirh-pour-la-gestion-des-ressources-humaines/',
#  'https://www.creer-une-entreprise.com/les-avantages-du-portage-salarial-pour-les-metiers-de-linformatique/',
#  'https://www.creer-une-entreprise.com/les-coulisses-de-la-recherche-et-developpement-chez-pampers/',
#  'https://www.creer-une-entreprise.com/chaussures-de-securite-pour-le-travail-guide-complet/',
#  'https://www.creer-une-entreprise.com/comment-realiser-une-analyse-granulometrique/',
#  'https://www.creer-une-entreprise.com/comprendre-le-salaire-et-levolution-de-carriere-pour-les-preparateurs-de-commandes-amazon/',
#  'https://www.creer-une-entreprise.com/quelles-sont-les-conditions-a-remplir-pour-obtenir-lesta/',
#  'https://www.creer-une-entreprise.com/comment-les-entreprises-peuvent-elles-etre-plus-durables/',
#  'https://www.creer-une-entreprise.com/comment-creer-une-sas-en-ligne/',
#  'https://www.creer-une-entreprise.com/quels-types-demballages-utiliser-pour-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/pourquoi-faire-appel-a-une-agence-pour-votre-communication/',
#  'https://www.creer-une-entreprise.com/comment-mailchimp-peut-ameliorer-la-performance-de-votre-campagne-marketing/',
#  'https://www.creer-une-entreprise.com/croissance-a-linternational-les-meilleures-opportunites-pour-les-entreprises-en-expansion/',
#  'https://www.creer-une-entreprise.com/comprendre-limportance-de-la-traduction-assermentee-dans-les-transactions-financieres-internationales/',
#  'https://www.creer-une-entreprise.com/comment-optimiser-sa-chaine-logistique/',
#  'https://www.creer-une-entreprise.com/comment-batir-une-marque-employeur-coherente/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/entreprises-equipez-votre-hall-dentree-efficacement-avec-ces-quelques-equipements/',
#  'https://www.creer-une-entreprise.com/pourquoi-un-sac-publicitaire-est-il-indispensable-pour-les-professionnels/',
#  'https://www.creer-une-entreprise.com/les-contrats-dassurance-pour-entreprise-comment-utiliser-un-comparateur-pour-trouver-le-meilleur-tarif/',
#  'https://www.creer-une-entreprise.com/dernieres-tendances-en-marketing-digital-pour-les-pme-strategies-incontournables-pour-ameliorer-votre-visibilite-en-ligne/',
#  'https://www.creer-une-entreprise.com/comment-creer-un-plan-de-marketing-digital-pour-votre-entreprise-2/',
#  'https://www.creer-une-entreprise.com/quel-statut-juridique-choisir-pour-votre-entreprise-guide-complet-de-la-civilite-formelle/',
#  'https://www.creer-une-entreprise.com/5-facons-de-rendre-votre-site-web-plus-rapide-a-charger/',
#  'https://www.creer-une-entreprise.com/le-packaging-un-indispensable-pour-les-commercants/',
#  'https://www.creer-une-entreprise.com/utilisation-des-etiquettes-americaines-pour-la-classification/',
#  'https://www.creer-une-entreprise.com/pourquoi-la-protection-incendie-est-elle-si-importante-pour-les-datacenters/',
#  'https://www.creer-une-entreprise.com/comment-les-pratiques-alimentaires-omnivores-peuvent-contribuer-a-la-protection-de-lenvironnement/',
#  'https://www.creer-une-entreprise.com/secretariat-externalise-les-avantages/',
#  'https://www.creer-une-entreprise.com/pourquoi-souscrire-une-mutuelle-sante/',
#  'https://www.creer-une-entreprise.com/comment-contacter-une-entreprise-de-securite-incendie/',
#  'https://www.creer-une-entreprise.com/comment-promouvoir-son-entreprise-avec-des-impressions-personnalisees/',
#  'https://www.creer-une-entreprise.com/gestion-de-litiges-en-entreprise-conseils-pour-eviter-les-conflits-avec-vos-clients-et-partenaires/',
#  'https://www.creer-une-entreprise.com/comment-promouvoir-votre-podcast/',
#  'https://www.creer-une-entreprise.com/comment-organiser-vos-taches-pour-mieux-gerer-vos-objectifs/',
#  'https://www.creer-une-entreprise.com/entrepreneur-quelle-assurance-auto-maaf-vous-faut-il/',
#  'https://www.creer-une-entreprise.com/zoom-sur-les-publicites-gonflables/',
#  'https://www.creer-une-entreprise.com/solution-innovante-denvoi-de-sms-en-masse/',
#  'https://www.creer-une-entreprise.com/comparer-les-avantages-et-inconvenients-des-differents-types-de-societes-pour-choisir-la-meilleure-option/',
#  'https://www.creer-une-entreprise.com/manutention-agricole-les-nouveaux-materiels-qui-simplifient-vos-taches/',
#  'https://www.creer-une-entreprise.com/pourquoi-utiliser-les-outils-numeriques-dans-la-planification-des-reunions/',
#  'https://www.creer-une-entreprise.com/entrepreneur-securisez-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/comment-choisir-une-societe-de-gestion-hoteliere/',
#  'https://www.creer-une-entreprise.com/comment-digitaliser-ses-espaces-de-travail/',
#  'https://www.creer-une-entreprise.com/les-astuces-pour-bien-utiliser-son-service-apres-vente-telephonique/',
#  'https://www.creer-une-entreprise.com/pourquoi-digitaliser-les-entretiens-individuels-annuels/',
#  'https://www.creer-une-entreprise.com/les-avantages-de-la-signature-electronique/',
#  'https://www.creer-une-entreprise.com/franchise-comment-booster-vos-performances/',
#  'https://www.creer-une-entreprise.com/les-clauses-abusives-a-eviter-dans-les-contrats-de-travail/',
#  'https://www.creer-une-entreprise.com/quelles-sont-les-meilleures-options-pour-tenir-la-comptabilite-de-son-entreprise/',
#  'https://www.creer-une-entreprise.com/proteger-vos-marques-et-brevets-en-entreprise-tout-ce-que-vous-devez-savoir-sur-la-propriete-intellectuelle/',
#  'https://www.creer-une-entreprise.com/comment-booster-sa-communication/',
#  'https://www.creer-une-entreprise.com/portage-salarial-immobilier/',
#  'https://www.creer-une-entreprise.com/comment-rendre-une-publication-commerciale-attractive/',
#  'https://www.creer-une-entreprise.com/prospection-telephonique-btob-3-raisons-dexternaliser-votre-campagne/',
#  'https://www.creer-une-entreprise.com/comment-bien-choisir-votre-flexible/',
#  'https://www.creer-une-entreprise.com/pourquoi-utiliser-un-logiciel-de-gestion-des-ressources-humaines/',
#  'https://www.creer-une-entreprise.com/comment-bien-gerer-les-ressources-humaines/',
#  'https://www.creer-une-entreprise.com/comment-transformer-votre-entreprise-vers-une-entreprise-environnement-developpement-durable/',
#  'https://www.creer-une-entreprise.com/credit-mutuel-maine-anjou-basse-normandie-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.creer-une-entreprise.com/les-procedures-efficaces-pour-recuperer-vos-creances-impayees/',
#  'https://www.creer-une-entreprise.com/3-logiciels-indispensables-dans-la-toolbox-des-start-ups/',
#  'https://www.creer-une-entreprise.com/choisissez-votre-meilleur-courtier-en-ligne/',
#  'https://www.creer-une-entreprise.com/teams-la-plateforme-collaborative-de-visioconference-microsoft/',
#  'https://www.creer-une-entreprise.com/quel-est-linteret-de-faire-appel-a-un-traiteur-pour-son-evenement-dentreprise/',
#  'https://www.creer-une-entreprise.com/zoom-logiciel-de-productivite-entreprise-collaboratif/',
#  'https://www.creer-une-entreprise.com/processus-de-recrutement-ces-5-erreurs-qui-peuvent-tout-ruiner/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/quatre-astuces-pour-bien-gerer-une-petite-entreprise/',
#  'https://www.creer-une-entreprise.com/comment-deposer-une-rupture-conventionnelle/',
#  'https://www.creer-une-entreprise.com/comment-ameliorer-sa-visibilite-dans-google/',
#  'https://www.creer-une-entreprise.com/domiciliation-dentreprise-comment-ca-fonctionne/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-criteres-de-choix-dune-banque-professionnelle-pour-son-entreprise/',
#  'https://www.creer-une-entreprise.com/developper-son-entreprise-en-russie-nos-conseils/',
#  'https://www.creer-une-entreprise.com/comment-tenir-la-comptabilite-de-son-entreprise-a-jour/',
#  'https://www.creer-une-entreprise.com/comment-creer-une-entreprise/',
#  'https://www.creer-une-entreprise.com/comment-lever-efficacement-des-fonds-pour-developper-son-entreprise/',
#  'https://www.creer-une-entreprise.com/espace-de-coworking-un-milieu-propice-pour-developper-son-projet/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-differents-pti-dati/',
#  'https://www.creer-une-entreprise.com/les-enjeux-juridiques-de-la-protection-des-donnees-en-entreprise-comment-respecter-la-nouvelle-reglementation/',
#  'https://www.creer-une-entreprise.com/pourquoi-les-competences-sont-elles-plus-importantes-que-lexperience-professionnelle/',
#  'https://www.creer-une-entreprise.com/avantages-des-services-dexternalisation-pour-les-entreprises/',
#  'https://www.creer-une-entreprise.com/le-marketing-un-pilier-essentiel-pour-la-croissance-des-entreprises/',
#  'https://www.creer-une-entreprise.com/comment-ouvrir-un-compte-professionnel-gratuit-en-ligne/',
#  'https://www.creer-une-entreprise.com/5-astuces-pour-ameliorer-votre-strategie-marketing-dentreprise/',
#  'https://www.creer-une-entreprise.com/les-tendances-actuelles-en-matiere-dimpression-pour-les-supports-de-communication/',
#  'https://www.creer-une-entreprise.com/comment-optimiser-la-gestion-de-vos-stocks-et-la-logistique/',
#  'https://www.creer-une-entreprise.com/creation-dentreprise-3-documents-indispensables/',
#  'https://www.creer-une-entreprise.com/optimisation-de-votre-site-wordpress-trouver-lagence-qui-vous-convient/',
#  'https://www.creer-une-entreprise.com/les-solutions-acoustiques-pour-lindustrie-cest-maintenant/',
#  'https://www.creer-une-entreprise.com/en-quoi-consiste-lusinage-et-dans-quels-secteurs-est-il-utilise/',
#  'https://www.creer-une-entreprise.com/4-excellentes-raisons-de-sadresser-a-un-specialiste-en-ligne-de-la-vente-de-materiel-chr/',
#  'https://www.creer-une-entreprise.com/beneficier-dune-meilleure-offre-de-sport-pour-les-salaries/',
#  'https://www.creer-une-entreprise.com/comment-trouver-un-macon-pres-de-chez-vous/',
#  'https://www.creer-une-entreprise.com/quel-est-le-meilleur-logiciel-pour-centre-dappel/',
#  'https://www.creer-une-entreprise.com/quels-sont-les-statuts/',
#  'https://www.creer-une-entreprise.com/business-comment-reussir-son-implantation-a-paris/',
#  'https://www.creer-une-entreprise.com/creation-de-societe-aux-usa-la-fiscalite-dans-le-delaware/',
#  'https://www.creer-une-entreprise.com/une-conception-graphique-efficace-pour-votre-entreprise/',
#  'https://www.creer-une-entreprise.com/quel-est-limportance-du-droit-des-affaires/',
#  'https://www.creer-une-entreprise.com/ouvrir-une-franchise-en-lien-avec-le-centre-auto/',
#  'https://www.creer-une-entreprise.com/quel-avocat-a-saint-etienne-contacter-pour-un-litige-immobilier/',
#  'https://www.creer-une-entreprise.com/quelle-forme-juridique-choisir-pour-sa-societe/',
#  'https://www.creer-une-entreprise.com/creation-dentreprise-les-etapes-primordiales/',
#  'https://www.creer-une-entreprise.com/quelle-assurance-auto-entrepreneur/',
#  'https://www.creer-une-entreprise.com/professionnel-du-domaine-de-lagroalimentaire-pourquoi-contacter-un-fabricant-de-machines-industrielles-sur-mesure/',
#  'https://www.creer-une-entreprise.com/ou-se-rendre-pour-optimiser-les-flux-dans-son-industrie/',
#  'https://www.creer-une-entreprise.com/experience-client-ces-4-erreurs-qui-peuvent-tout-ruiner-en-2022/',
#  'https://www.creer-une-entreprise.com/site-web-gagnez-de-la-visibilite-en-4-etapes/',
#  'https://www.creer-une-entreprise.com/zoom-sur-les-demarches-a-entreprendre-pour-prevenir-les-risques-psychosociaux/',
#  'https://www.creer-une-entreprise.com/comment-faire-une-domiciliation-dentreprise/',
#  'https://www.creer-une-entreprise.com/pourquoi-rediger-des-statuts/',
#  'https://www.creer-une-entreprise.com/entreprise-conseils-pour-une-organisation-reussie/',
#  'https://www.creer-une-entreprise.com/comment-utiliser-son-dif-en-2021/',
#  'https://www.creer-une-entreprise.com/ou-exercer-le-metier-dexpert-comptable/',
#  'https://www.creer-une-entreprise.com/comment-desinfecter-des-locaux/',
#  'https://www.creer-une-entreprise.com/comment-creer-un-produit-innovant/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/',
#  'https://www.creer-une-entreprise.com/arkevia-acces-a-vos-documents-et-gestion-simplifiee/',
#  'https://www.creer-une-entreprise.com/optimisation-des-ventes-en-boutique-limportance-dun-bon-systeme-de-caisse-en-ligne/',
#  'https://www.creer-une-entreprise.com/simulateur-de-pret-personnel-pourquoi-lutiliser/',
#  'https://www.creer-une-entreprise.com/mettez-toutes-les-chances-de-votre-cote-en-vous-offrant-un-maximum-de-visibilite/',
#  'https://www.creer-une-entreprise.com/comprendre-la-revalorisation-de-la-valeur-du-point-de-la-convention-66/']

# %% [markdown]
# ### Récupérer les infos qu'on souhaite sur chaque article

# %%
def get_article_info(r, url_article):
    # Liste de variables
    noms_variables = [
        'url',  # URL scrapée
        'canonical_url', 'slug', 'meta_title', 'meta_desc',  # Infos issues de la balise meta
        'date_published', 'date_modified',  # Infos dates
        'author',  # Parfois en meta
        'title', 'category', 'views', 'reading_time',  # Metadonnées contenues ailleurs que dans la balise meta
        'content', 'raw_content'  # Contenu de la page
    ]
    
    # Initialisation du dictionnaire
    data = {nom: np.nan for nom in noms_variables}
    
    data['url'] = url_article
    
    soup = BeautifulSoup(r.content, 'lxml')
    
    try:
        data['canonical_url'] = soup.find('link', {'rel': 'canonical'})['href']
    except:
        pass
    
    try:
        data['slug'] = data['canonical_url'].split('/')[-2] if data['canonical_url'] else np.nan
    except:
        pass

    try:
        data['meta_title'] = soup.find('meta', {'property': 'og:title'})['content']
    except:
        pass

    try:
        data['meta_desc'] = soup.find('meta', {'property': 'og:description'})['content']
    except:
        pass

    try:
        data['date_published'] = pd.to_datetime(soup.find('meta', {'property': 'article:published_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['date_modified'] = pd.to_datetime(soup.find('meta', {'property': 'article:modified_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['author'] = soup.find("meta", {'name': 'author'})['content']
    except:
        try:
            data['author'] = soup.find(class_="author").text.split('Publié par ')[-1]
        except:
            pass

    try:
        data['title'] = soup.find('h1').text
    except:
        pass

    try:
        data['category'] = [x.text for x in soup.find_all(class_="post-category")]
    except:
        pass

    try:
        data['views'] = int(soup.find('div', class_=lambda x: x and x.startswith('views')).text)
    except:
        pass

    try:
        data['reading_time'] = int(soup.find('meta', {'name': 'twitter:data2'})['content'].split(' ')[0]) if soup.find('meta', {'name': 'twitter:data2'}) and 'minutes' in soup.find('meta', {'name': 'twitter:data2'})['content'] else np.nan
    except:
        pass

    try:
        data['content'] = BeautifulSoup(str(soup.find("div", class_="td-post-content")), 'lxml').get_text()
    except:
        pass

    try:
        data['raw_content'] = str(soup.find("div", class_="td-post-content"))
    except:
        pass

    # Ajout de features
    data['length'] = len(str(data['content']).split())
    
    if pd.notnull(data['date_published']):
        data['days_since_published'] = int((pd.Timestamp.now(tz='UTC') - data['date_published']).days)
    else:
        data['days_since_published'] = np.nan
    
    # Création de la série
    series = pd.Series(data)
    series.name = url_article
    
    # Ajout de features supplémentaires
    if pd.notnull(data.get('views')) and pd.notnull(data.get('days_since_published')):
        series['views_daily'] = series['views'] / (1+series['days_since_published'])
        series['views_monthly'] = series['views_daily'] * 30
    else:
        series['views_daily'] = np.nan
        series['views_monthly'] = np.nan
    
    series['website'] = top_url
    
    return series

# %% [markdown]
# ## Fonction finale

# %%
article_list = get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
# 100%|██████████| 14/14 [00:05<00:00,  2.47it/s]

# %% [markdown]
# ### Fonction finale

# %%
# Import des packages
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Initialisation du compteur
start_time = time.time()

# Fonction principale qui sauvegarde le DataFrame dans un fichier CSV et le retourne
def scrape_all_articles(urls, batch_size=250, max_workers=20):
    # Initialisation d'une session réutilisable
    session = rq.Session()

    # Création d'une fonction qui traite chaque URL
    def process_url(url):
            try:
                r = session.get(url)
                return get_article_info(r, url)
            except Exception as e:
                print(f"Erreur pour {url}: {str(e)}")
                return pd.Series(name=url)

    # Utilise ThreadPoolExecutor pour paralléliser le traitement
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Parcourt la liste d'URLs par lots de taille 'batch_size'
        for i in range(0, len(urls), batch_size):
            # Extrait un lot d'URLs
            batch = urls[i:i+batch_size]
            # Crée et soumet des tâches pour chaque URL du lot
            futures = [executor.submit(process_url, url) for url in batch]
            
            # Traite les résultats au fur et à mesure qu'ils sont terminés
            for future in tqdm(as_completed(futures), total=len(batch), desc=f"Batch {i//batch_size + 1} / {len(urls)//batch_size+1}"):
                # Récupère le résultat de la tâche
                result = future.result()
                # Si le résultat n'est pas None (pas d'erreur), l'ajoute aux résultats
                if result is not None:
                    results.append(result)
    
    # Création du DataFrame final
    df_final = pd.DataFrame(results)
    
    # Ajout de colonnes calculées
    df_final['website'] = top_url
    df_final['scraping_date'] = pd.Timestamp.now(tz='UTC')

    df_final.columns = ['article_url', 'article_canonical_url', 'article_slug',
       'article_meta_title', 'article_meta_desc', 'article_date_published',
       'article_date_modified', 'article_author', 'article_title',
       'article_category', 'article_views', 'article_reading_time',
       'article_content', 'article_raw_content', 'article_length',
       'days_since_published', 'article_views_daily', 'article_views_monthly',
       'website', 'scraping_date']

    # Sauvegarde en CSV
    df_final.to_csv(f'scraping_{abbr}.csv', sep='|', index=True)
    print(f"Scraping terminé. Total d'articles : {len(df_final)}")
    return df_final

df = scrape_all_articles(article_list)

end_time = time.time()
print(end_time - start_time)
# Out:
# Batch 1 / 4: 100%|██████████| 250/250 [00:26<00:00,  9.47it/s]
# Batch 2 / 4: 100%|██████████| 250/250 [00:25<00:00,  9.94it/s]
# Batch 3 / 4: 100%|██████████| 250/250 [00:26<00:00,  9.35it/s]
# Batch 4 / 4: 100%|██████████| 75/75 [00:06<00:00, 11.20it/s]
# Scraping terminé. Total d'articles : 825
# 85.19610214233398

# %%
# Création d'un rapport de profil avec pandas_profiling
profile = ProfileReport(df, title=f"{abbr.title()} Scraping Report", explorative=True)

# Génération du rapport au format HTML
profile.to_file(f"scraping_report_{abbr}.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\MSI\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
