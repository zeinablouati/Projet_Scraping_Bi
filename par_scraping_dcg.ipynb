# %% [markdown]
# # Scraping DCG.media

# %%
### SCRAPING
import requests as rq
from bs4 import BeautifulSoup

### DATABASES
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

### VISUALISATION
#import plotly.express as px

### DIVERS
from tqdm import tqdm

### FORMAT
from datetime import datetime, timezone
import time
import json

# %% [markdown]
# ## Définition des variables

# %%
website = 's-finance'
abbr = 'sfi'
tld = '.fr'

# %%
page_number = 1
top_url = f'https://www.{website+tld}'
top_search_url = f'{top_url}/page/{page_number}/?s'

# %% [markdown]
# ## Définition des fonctions

# %% [markdown]
# ### Obtenir le nombre de pages de résultats de recherche

# %%
def get_max_page_results(top_search_url):
    r = rq.get(top_search_url)
    soup = BeautifulSoup(r.content)
    page_final = soup.find_all('a', class_ = 'page-numbers')
    return int(page_final[-2].text)
get_max_page_results(top_search_url)
# Out:
# 17

# %% [markdown]
# ### Obtenir la liste des pages de résultats de recherche

# %%
def get_all_results_pages(page_final):
    urls = []
    for i in range(page_final):
        i = f'{top_url}/page/{i+1}/?s'
        urls.append(i)
    return urls
get_all_results_pages(get_max_page_results(top_search_url))
# Out:
# ['https://www.s-finance.fr/page/1/?s',
#  'https://www.s-finance.fr/page/2/?s',
#  'https://www.s-finance.fr/page/3/?s',
#  'https://www.s-finance.fr/page/4/?s',
#  'https://www.s-finance.fr/page/5/?s',
#  'https://www.s-finance.fr/page/6/?s',
#  'https://www.s-finance.fr/page/7/?s',
#  'https://www.s-finance.fr/page/8/?s',
#  'https://www.s-finance.fr/page/9/?s',
#  'https://www.s-finance.fr/page/10/?s',
#  'https://www.s-finance.fr/page/11/?s',
#  'https://www.s-finance.fr/page/12/?s',
#  'https://www.s-finance.fr/page/13/?s',
#  'https://www.s-finance.fr/page/14/?s',
#  'https://www.s-finance.fr/page/15/?s',
#  'https://www.s-finance.fr/page/16/?s',
#  'https://www.s-finance.fr/page/17/?s']

# %% [markdown]
# ### Obtenir tous les liens des articles sur une page de recherche

# %%
def get_articles_on_page(search_results):
    urls_articles = []
    s = rq.Session()
    for p in tqdm(search_results):
        r = s.get(p)
        soup = BeautifulSoup(r.content)
        articles = soup.find_all('h2', class_ = 'title')
        for article in articles:
            url = article.find('a', href=True)['href']
            urls_articles.append(url)
    return urls_articles

# %%
get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
# 100%|██████████| 17/17 [00:09<00:00,  1.85it/s]
# ['https://www.s-finance.fr/comprendre-les-plans-de-retraite-dentreprise-perco-pere-percoi-et-optimiser-votre-avenir-financier/',
#  'https://www.s-finance.fr/indexeuro-px1-comprendre-cet-indice-boursier-europeen/',
#  'https://www.s-finance.fr/monportailsecuritas-fr-comment-se-connecter-et-acceder-aux-outils/',
#  'https://www.s-finance.fr/naviguer-dans-lunivers-de-cmut-direct-pro-guide-complet-pour-les-pme/',
#  'https://www.s-finance.fr/arkevia-mon-compte-comment-acceder-et-gerer-votre-espace/',
#  'https://www.s-finance.fr/credit-agricole-code-banque-trouver-votre-code/',
#  'https://www.s-finance.fr/indexeuro-px1-indice-boursier-europeen-et-ses-implications/',
#  'https://www.s-finance.fr/calcul-salaire-net-depuis-brut-de-1900e-methode-simple-et-rapide/',
#  'https://www.s-finance.fr/comprendre-les-pcea-en-comptabilite-definition-et-enjeux-essentiels/',
#  'https://www.s-finance.fr/banque-101-comprendre-lintitule-de-votre-compte/',
#  'https://www.s-finance.fr/epargne-salariale-la-poste-comprendre-les-avantages-et-fonctionnement/',
#  'https://www.s-finance.fr/comprendre-le-roc-un-indicateur-cle-de-la-sante-financiere-dune-entreprise/',
#  'https://www.s-finance.fr/banque-postale-comment-savoir-de-quel-centre-financier-vous-dependez/',
#  'https://www.s-finance.fr/comment-fonctionne-le-mobile-banking/',
#  'https://www.s-finance.fr/mon-compte-nickel-se-connecter-a-son-compte-client/',
#  'https://www.s-finance.fr/cybermut-filbanque-du-credit-mutuel-connexion-au-compte/',
#  'https://www.s-finance.fr/est-ce-que-le-trading-est-legal/',
#  'https://www.s-finance.fr/les-horaires-pour-joindre-le-3639-de-la-banque-postale/',
#  'https://www.s-finance.fr/quels-sont-les-entreprises-du-cac-40/',
#  'https://www.s-finance.fr/comment-convertir-des-bitcoins-en-euros/',
#  'https://www.s-finance.fr/les-domaines-a-suivre-pour-investir-en-2025/',
#  'https://www.s-finance.fr/le-role-des-plateformes-numeriques-dans-la-popularisation-des-pieces-de-collection-aupres-des-nouvelles-generations/',
#  'https://www.s-finance.fr/maximiser-vos-cheques-vacances-a-la-retraite-conseils-et-astuces/',
#  'https://www.s-finance.fr/comptabilisation-des-charges-constatees-davance-maitrisez-les-cca/',
#  'https://www.s-finance.fr/plafond-paiement-especes-comprendre-les-regles-et-restrictions/',
#  'https://www.s-finance.fr/soldes-intermediaires-de-gestion-en-comptabilite-maitrisez-le-sig/',
#  'https://www.s-finance.fr/remplir-un-cheque-correctement-etapes-cles-pour-eviter-les-erreurs/',
#  'https://www.s-finance.fr/pourquoi-et-comment-creer-sa-sasu/',
#  'https://www.s-finance.fr/comment-proceder-pour-la-creation-dune-societe-offshore/',
#  'https://www.s-finance.fr/frais-de-dossier-assurance-auto-maaf-combien-ca-coute/',
#  'https://www.s-finance.fr/decouvrez-quel-salaire-est-requis-pour-emprunter-150-000-euros/',
#  'https://www.s-finance.fr/pampers-comment-economiser-sur-le-budget-couches/',
#  'https://www.s-finance.fr/artisan-du-btp-comment-trouver-la-meilleure-assurance-decennale/',
#  'https://www.s-finance.fr/comment-trader-sur-metatrader-4-les-conseils/',
#  'https://www.s-finance.fr/pret-sans-enquete-de-credit/',
#  'https://www.s-finance.fr/peut-on-contracter-un-pret-pour-un-mariage/',
#  'https://www.s-finance.fr/quelles-sont-les-raisons-dinvestir-dans-lor/',
#  'https://www.s-finance.fr/caisse-depargne-rhone-alpes-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.s-finance.fr/trois-raisons-de-vendre-son-or-en-belgique/',
#  'https://www.s-finance.fr/rouler-sans-assurances-quels-sont-les-risques/',
#  'https://www.s-finance.fr/comment-ouvrir-un-commerce-sans-apport/',
#  'https://www.s-finance.fr/exploiter-au-maximum-un-simulateur-dassurance-voiture-conseils-et-astuces/',
#  'https://www.s-finance.fr/chomage-et-cotisation-retraite-comprendre-les-enjeux-pour-votre-futur/',
#  'https://www.s-finance.fr/calendrier-previsionnel-de-la-paie-des-professeurs-2024/',
#  'https://www.s-finance.fr/assurance-habitation-pour-etudiant-crous-choisir-le-contrat-adapte-a-votre-logement/',
#  'https://www.s-finance.fr/compte-joint-comment-louvrir/',
#  'https://www.s-finance.fr/la-theorie-des-points-pivots-un-indicateur-cle-pour-les-traders/',
#  'https://www.s-finance.fr/simuler-le-portage-salarial-pourquoi-excel-est-il-votre-meilleur-allie/',
#  'https://www.s-finance.fr/comment-investir-dans-la-crypto-monnaie-guide-pour-les-debutants/',
#  'https://www.s-finance.fr/assurance-etudiant-groupama-offre-les-meilleurs-tarifs/',
#  'https://www.s-finance.fr/quels-sont-les-avantages-et-inconvenients-de-la-strategie-long-short/',
#  'https://www.s-finance.fr/monnaies-specifiques-dans-les-jeux-video-un-succes-grandissant/',
#  'https://www.s-finance.fr/1xbit-vous-invite-a-visiter-la-crypto-city/',
#  'https://www.s-finance.fr/comment-ouvrir-un-compte-sur-etoro/',
#  'https://www.s-finance.fr/quelle-est-la-meilleure-banque-en-2021/',
#  'https://www.s-finance.fr/les-alternatives-aux-banques-pour-mon-pret-entreprise/',
#  'https://www.s-finance.fr/comment-avoir-un-avis-de-credit-favorable-en-ligne/',
#  'https://www.s-finance.fr/quelle-banque-choisir-pour-un-jeune-de-17-ans/',
#  'https://www.s-finance.fr/regions-francaises-ou-le-salaire-de-moniteur-educateur-est-le-plus-eleve/',
#  'https://www.s-finance.fr/reformes-necessaires-pour-optimiser-le-paiement-des-enseignants/',
#  'https://www.s-finance.fr/evolution-de-la-valeur-des-pieces-rares-de-2-euros-un-investissement-lucratif/',
#  'https://www.s-finance.fr/comment-la-digitalisation-transforme-le-secteur-de-linvestissement/',
#  'https://www.s-finance.fr/guide-complet-pour-resilier-votre-assurance-habitation-swisslife/',
#  'https://www.s-finance.fr/quelles-informations-rechercher-sur-les-forums-dassurance-auto-avant-de-souscrire-un-contrat/',
#  'https://www.s-finance.fr/les-frais-de-trading-sur-kucoin-comment-les-minimiser-et-maximiser-vos-profits/',
#  'https://www.s-finance.fr/comprendre-le-fonctionnement-de-la-retraite-pour-avocat/',
#  'https://www.s-finance.fr/devis-gratuit-assurance-auto-mma-comment-lobtenir/',
#  'https://www.s-finance.fr/pourquoi-le-bts-comptabilite-et-gestion-est-une-formation-incontournable-pour-les-metiers-de-la-finance/',
#  'https://www.s-finance.fr/3-conseils-pour-une-meilleure-gestion-de-vos-comptes-bancaires/',
#  'https://www.s-finance.fr/comment-resilier-son-assurance-habitation-maaf-en-ligne/',
#  'https://www.s-finance.fr/assurance-moto-payd-avis-et-retours-dexperience-sur-le-forum/',
#  'https://www.s-finance.fr/libelle-du-compte-explications-du-libelle-bancaire/',
#  'https://www.s-finance.fr/trading-en-ligne-le-choix-de-la-plateforme/',
#  'https://www.s-finance.fr/comment-facturer-un-service-de-nettoyage/',
#  'https://www.s-finance.fr/comment-choisir-la-meilleure-assurance-habitation-pour-votre-maison/',
#  'https://www.s-finance.fr/docuware-un-outil-de-travail-avec-diverses-fonctionnalites/',
#  'https://www.s-finance.fr/investir-au-mans-opportunites-dans-le-neuf/',
#  'https://www.s-finance.fr/assurance-vie-comment-integrer-des-scpi-a-votre-contrat/',
#  'https://www.s-finance.fr/quels-criteres-pour-choisir-une-banque-pro/',
#  'https://www.s-finance.fr/comprendre-les-enjeux-de-linvestissement-dans-les-monnaies-numeriques/',
#  'https://www.s-finance.fr/comment-choisir-la-meilleure-banque-pres-de-chez-moi-criteres-et-conseils-pratiques/',
#  'https://www.s-finance.fr/comprendre-les-prelevements-de-ace-european-group-sur-votre-compte-bancaire/',
#  'https://www.s-finance.fr/previsions-pour-le-cours-du-cuivre-au-kilogramme-en-2024/',
#  'https://www.s-finance.fr/tout-savoir-sur-larticle-669-du-cgi/',
#  'https://www.s-finance.fr/ou-trouver-un-code-de-parrainage-pour-trade-republic/',
#  'https://www.s-finance.fr/decouverte-de-sapheer-tout-savoir-sur-la-neobanque-innovante/',
#  'https://www.s-finance.fr/virement-ponctuel-tout-savoir-sur-son-fonctionnement-et-ses-benefices/',
#  'https://www.s-finance.fr/comptabilisation-des-loyers-percus-maitrisez-vos-ecritures-comptables/',
#  'https://www.s-finance.fr/decouverte-de-cryptoleo-en-2022-une-evidence-pour-crypto-casino-bet/',
#  'https://www.s-finance.fr/comment-obtenir-un-pret-viager-hypothecaire-chez-bnp-paribas/',
#  'https://www.s-finance.fr/le-meilleur-materiel-pour-miner-des-bitcoins/',
#  'https://www.s-finance.fr/floa-bank-mon-compte-connexion/',
#  'https://www.s-finance.fr/avis-sur-lead-camp-une-entreprise-pas-comme-les-autres/',
#  'https://www.s-finance.fr/comment-joindre-le-credit-foncier-de-france/',
#  'https://www.s-finance.fr/ou-jeter-les-cendres-de-la-cheminee/',
#  'https://www.s-finance.fr/comment-calculer-la-marge-sur-cout-direct/',
#  'https://www.s-finance.fr/comment-ca-marche-les-commande-sur-amazon/',
#  'https://www.s-finance.fr/comment-les-pme-et-pmi-simplifient-elles-la-gestion-des-sous-traitants-sur-leurs-chantiers/',
#  'https://www.s-finance.fr/comprendre-les-taux-dinteret-pour-un-credit-auto-tout-ce-que-vous-devez-savoir/',
#  'https://www.s-finance.fr/fiscalite-analyse-des-regimes-fiscaux-pour-eirl-et-eurl/',
#  'https://www.s-finance.fr/assurance-obseques-quels-sont-les-couts-moyens-en-2024/',
#  'https://www.s-finance.fr/comprendre-le-fonctionnement-de-la-caisse-primaire-dassurance-maladie-de-clermont-ferrand-conseils-et-astuces/',
#  'https://www.s-finance.fr/carinvest-avis-ce-que-vous-devez-savoir-avant-dinvestir/',
#  'https://www.s-finance.fr/30-000-brut-en-net-calcul-et-explications/',
#  'https://www.s-finance.fr/1800-euros-net-en-brut-evaluation-et-comprehension/',
#  'https://www.s-finance.fr/comment-une-crypto-prend-de-la-valeur/',
#  'https://www.s-finance.fr/cest-quoi-le-resultat-operationnel-courant/',
#  'https://www.s-finance.fr/les-bienfaits-de-www-ca-centreloire-fr-compte-pour-les-clients/',
#  'https://www.s-finance.fr/mon-portail-securitas-tout-ce-quil-faut-savoir-sur-cet-outil-professionnel/',
#  'https://www.s-finance.fr/mon-gustave-zoom-sur-ce-nouveau-comparateur-dassurances/',
#  'https://www.s-finance.fr/guide-des-prix-de-location-de-bureaux-au-mtre-carr-paris/',
#  'https://www.s-finance.fr/droits-patrimoniaux-et-extrapatrimoniaux-comprendre-la-difference/',
#  'https://www.s-finance.fr/indemnisation-accident-corporel-calcul-et-montants-a-connaitre/',
#  'https://www.s-finance.fr/comment-bien-selectionner-une-assurance-pour-chateau/',
#  'https://www.s-finance.fr/les-cles-pour-bien-comprendre-les-options-call-et-put-pour-les-debutants/',
#  'https://www.s-finance.fr/les-exclusions-de-lassurance-trottinette-electrique-chez-mae/',
#  'https://www.s-finance.fr/vers-une-obligation-de-lagrement-psan-pour-les-crypto-societes/',
#  'https://www.s-finance.fr/comment-resilier-votre-assurance-habitation-pacifique-chez-credit-agricole/',
#  'https://www.s-finance.fr/besoin-de-contacter-credit-agricole-assurance-emprunteur-voici-comment-faire/',
#  'https://www.s-finance.fr/pourquoi-les-mineurs-de-bitcoin-sont-ils-si-importants/',
#  'https://www.s-finance.fr/lepargne-immobiliere-cest-quoi/',
#  'https://www.s-finance.fr/cest-quoi-le-cfd-en-cryptomonnaie/',
#  'https://www.s-finance.fr/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.s-finance.fr/comment-calculer-un-ratio-de-rentabilite/',
#  'https://www.s-finance.fr/comment-declarer-un-deces-aux-organismes/',
#  'https://www.s-finance.fr/quel-est-le-role-de-lurssaf/',
#  'https://www.s-finance.fr/quels-sont-les-objectifs-de-la-gestion-financiere/',
#  'https://www.s-finance.fr/optimisez-votre-experience-bancaire-avec-credit-mutuel-de-bretagne-en-ligne/',
#  'https://www.s-finance.fr/comprendre-le-trading-et-la-gestion-des-pips-guide-pour-debutants/',
#  'https://www.s-finance.fr/cadessavoie-services-et-contact/',
#  'https://www.s-finance.fr/les-etapes-cles-pour-changer-dassurance-emprunteur-efficacement/',
#  'https://www.s-finance.fr/reprenez-le-controle-sur-vos-finances-en-suivant-nos-conseils/',
#  'https://www.s-finance.fr/simplifier-la-gestion-des-salaires-les-avantages-des-logiciels-de-paie/',
#  'https://www.s-finance.fr/tout-savoir-sur-les-assurances-auto-jeune-conducteur-pour-chevaux-fiscaux-avec-notre-guide-complet/',
#  'https://www.s-finance.fr/dif-cpf-comment-le-calculer-rapidement-et-facilement/',
#  'https://www.s-finance.fr/quel-est-le-role-dun-avocat-fiscaliste/',
#  'https://www.s-finance.fr/succession-sur-livret-a-regles-et-demarches/',
#  'https://www.s-finance.fr/trois-questions-a-vous-poser-avant-de-vous-engager-avec-une-entreprise/',
#  'https://www.s-finance.fr/comment-payer-moins-de-frais-bancaires/',
#  'https://www.s-finance.fr/optimisez-vos-voyages-avec-la-carte-bleue-nomade-de-la-banque-postale/',
#  'https://www.s-finance.fr/les-avantages-insoupconnes-de-lecureuil-internet-pour-vos-finances-personnelles/',
#  'https://www.s-finance.fr/comment-fonctionne-western-union/',
#  'https://www.s-finance.fr/quest-ce-quune-paire-de-devises/',
#  'https://www.s-finance.fr/et-si-vous-choisissiez-un-partenaire-bancaire-en-ligne/',
#  'https://www.s-finance.fr/les-bases-a-connaitre-avant-de-se-lancer-dans-laventure-des-marches-financiers/',
#  'https://www.s-finance.fr/pourquoi-est-il-interessant-dinvestir-dans-un-programme-immobilier-neuf/',
#  'https://www.s-finance.fr/demystifier-les-titres-de-propriete-tout-ce-que-vous-devez-savoir/',
#  'https://www.s-finance.fr/ace-european-group-un-bastion-de-la-securite-financiere-en-europe/',
#  'https://www.s-finance.fr/e-carte-bleue-nomade-avantages-fonctionnement-et-avis/',
#  'https://www.s-finance.fr/comment-calculer-son-tjm-en-portage-salarial/',
#  'https://www.s-finance.fr/comptabilite-comment-trouver-son-expertcomptable/',
#  'https://www.s-finance.fr/les-revenus-de-didier-deschamps-un-examen-financier/',
#  'https://www.s-finance.fr/pourquoi-le-prelevement-automatique-devient-incontournable-pour-les-entreprises/',
#  'https://www.s-finance.fr/dans-quelles-situations-faire-appel-un-spcialiste-en-management-de-transition/',
#  'https://www.s-finance.fr/dans-quelles-situations-faire-appel-a-un-specialiste-en-management-de-transition/',
#  'https://www.s-finance.fr/les-recours-en-cas-de-refus-de-plan-de-surendettement-par-un-creancier/',
#  'https://www.s-finance.fr/les-avantages-de-lestimation-immobiliere-en-ligne-rapide-gratuite-et-fiable/',
#  'https://www.s-finance.fr/le-notaire-votre-allie-pour-securiser-vos-investissements-immobiliers/',
#  'https://www.s-finance.fr/apres-combien-de-temps-les-dettes-seffacent-elles-apres-un-jugement/',
#  'https://www.s-finance.fr/simplifier-les-transactions-grace-aux-iban-virtuels-pour-les-entreprises/',
#  'https://www.s-finance.fr/les-avantages-du-portage-salarial/',
#  'https://www.s-finance.fr/pourquoi-contacter-un-avocat-fiscaliste/',
#  'https://www.s-finance.fr/comment-la-mutuelle-chat-peut-prevenir-les-couts-veterinaires-eleves/',
#  'https://www.s-finance.fr/les-astuces-pour-choisir-la-meilleure-assurance-acm/',
#  'https://www.s-finance.fr/4-pratiques-pour-optimiser-la-comptabilisation-des-comptes-a-terme/',
#  'https://www.s-finance.fr/quel-credit-pour-les-particuliers-au-luxembourg/',
#  'https://www.s-finance.fr/quelle-est-la-particularite-du-pret-economie-denergie/',
#  'https://www.s-finance.fr/investir-en-spci/',
#  'https://www.s-finance.fr/comment-choisir-son-assurance-auto/',
#  'https://www.s-finance.fr/limmobilier-a-nice-ce-quil-faut-savoir-avant-dacheter/',
#  'https://www.s-finance.fr/quelles-sont-les-meilleures-plateformes-de-crypto-monnaies/',
#  'https://www.s-finance.fr/reussir-son-projet-immobilier-contactez-des-professionnels/',
#  'https://www.s-finance.fr/comment-les-solutions-de-sante-peuvent-constituer-un-investissement-financier-intelligent-pour-le-bien-etre-a-long-terme/',
#  'https://www.s-finance.fr/limmobilier-fractionne-une-nouvelle-facon-de-devenir-proprietaire/',
#  'https://www.s-finance.fr/les-avantages-inedits-du-gfp-plan-sante-pour-les-familles/',
#  'https://www.s-finance.fr/les-bonnes-strategies-pour-reussir-en-tant-que-promoteur-immobilier/',
#  'https://www.s-finance.fr/comment-changer-de-banque-en-etant-en-surendettement/',
#  'https://www.s-finance.fr/les-investissements-immobiliers-lmnp-pourquoi-devez-vous-les-choisir/',
#  'https://www.s-finance.fr/coopanet-banque-solidaire-decouvrez-ses-services-et-engagements-ethiques/',
#  'https://www.s-finance.fr/comment-utiliser-un-simulateur-de-retraite-pour-planifier-son-avenir/',
#  'https://www.s-finance.fr/investir-en-suisse-ou-luxembourg-avantages-et-fiscalite-pour-votre-epargne/',
#  'https://www.s-finance.fr/quelles-sont-les-entreprises-cotees-en-bourse/',
#  'https://www.s-finance.fr/comment-construire-un-patrimoine-durable/',
#  'https://www.s-finance.fr/gestion-de-patrimoine-pourquoi-faire-appel-a-un-conseiller/',
#  'https://www.s-finance.fr/decryptage-du-releve-dinformation-dassurance-auto-ce-que-chaque-conducteur-doit-savoir/',
#  'https://www.s-finance.fr/credit-immobilier-quelles-sont-les-differentes-options-a-votre-disposition/',
#  'https://www.s-finance.fr/decryptage-de-la-rentabilite-dans-la-restauration/',
#  'https://www.s-finance.fr/les-criteres-a-prendre-en-compte-pour-comparer-les-assurances-habitation/',
#  'https://www.s-finance.fr/comment-maximiser-ses-profits-lors-des-hausses-du-marche-crypto/',
#  'https://www.s-finance.fr/le-lingot-dor-un-placement-sur-pour-securiser-votre-epargne/',
#  'https://www.s-finance.fr/les-avantages-dun-compte-en-ligne-avec-rib-immediat-pour-optimiser-sa-gestion-financiere/',
#  'https://www.s-finance.fr/les-aptitudes-fondamentales-pour-obtenir-un-metier-remunere-plus-de-100-000-euros-par-mois/',
#  'https://www.s-finance.fr/quels-sont-les-meilleurs-jours-pour-acheter-ses-actions-en-bourse/',
#  'https://www.s-finance.fr/quest-ce-quun-avocat-en-droit-des-societes/',
#  'https://www.s-finance.fr/comment-choisir-un-compte-ou-une-carte-sans-banque/',
#  'https://www.s-finance.fr/expert-comptable-avocat-les-enjeux-pour-les-entreprises/',
#  'https://www.s-finance.fr/les-criteres-a-prendre-en-compte-pour-comparer-les-offres-dassurance-moto-saisonniere/',
#  'https://www.s-finance.fr/decouvrez-les-opportunites-des-scpi-de-logistique/',
#  'https://www.s-finance.fr/comment-diversifier-ses-investissements-grace-au-crowdlending/',
#  'https://www.s-finance.fr/construction-de-maison-comment-choisir-correctement-son-terrain/',
#  'https://www.s-finance.fr/le-role-de-lexpert-comptable-dans-lunivers-du-mannequinat/',
#  'https://www.s-finance.fr/imputation-comptable-expliquee-comprendre-les-principes-essentiels/',
#  'https://www.s-finance.fr/confier-la-gestion-de-vos-biens-locatifs-meubles-a-un-expert-comptable-immobilier/',
#  'https://www.s-finance.fr/les-differents-types-de-contrats-dassurance-vie/',
#  'https://www.s-finance.fr/formulaire-2044-pour-2023-astuces-pour-reduire-votre-imposition/',
#  'https://www.s-finance.fr/guide-complet-pour-maitriser-le-formulaire-2072/',
#  'https://www.s-finance.fr/comment-optimiser-votre-tresorerie-avec-laffacturage/',
#  'https://www.s-finance.fr/pourquoi-investir-dans-lor-et-comment-le-vendre-au-meilleur-prix/',
#  'https://www.s-finance.fr/payer-avec-sa-montre-connectee-et-pourquoi-pas/',
#  'https://www.s-finance.fr/entreprises-pourquoi-se-faire-accompagner-pour-la-gestion-interne/',
#  'https://www.s-finance.fr/maximiser-la-valeur-de-votre-bien-immobilier-grace-aux-plateformes-numeriques-innovantes/',
#  'https://www.s-finance.fr/comment-choisir-sa-future-maison-dans-les-cotes-darmor/',
#  'https://www.s-finance.fr/5-regles-a-suivre-pour-un-bon-investissement-en-scpi/',
#  'https://www.s-finance.fr/les-cles-pour-reussir-sa-formation-en-finance/',
#  'https://www.s-finance.fr/financement-des-pme-en-2024-lere-des-banques-professionnelles-specialisees/',
#  'https://www.s-finance.fr/comment-choisir-entre-metatrader-5-et-metatrader-4-pour-votre-strategie-de-trading/',
#  'https://www.s-finance.fr/optez-pour-lassurance-auto-au-km-amaguiz-une-option-sur-mesure-pour-votre-budget-auto/',
#  'https://www.s-finance.fr/quel-est-le-rendement-dune-scpi/',
#  'https://www.s-finance.fr/comment-reduire-le-taux-annuel-effectif-global-taeg-de-votre-pret-immobilier/',
#  'https://www.s-finance.fr/comment-les-differents-facteurs-impactent-le-cout-de-votre-assurance-voiture/',
#  'https://www.s-finance.fr/pourquoi-louer-un-bureau-pour-votre-entreprise/',
#  'https://www.s-finance.fr/les-cles-de-la-reussite-pour-un-fonctionnement-harmonieux-dune-sci-familiale/',
#  'https://www.s-finance.fr/domiciliation-dentreprise-paris-8-berri/',
#  'https://www.s-finance.fr/la-lld-une-alternative-economique-a-lachat-dune-voiture-neuve/',
#  'https://www.s-finance.fr/assurance-auto-au-km-la-solution-ideale-pour-les-petits-rouleurs/',
#  'https://www.s-finance.fr/comment-devenir-conseiller-immobilier/',
#  'https://www.s-finance.fr/maximiser-lefficacite-de-votre-entreprise-grace-aux-systemes-de-vente-modernes/',
#  'https://www.s-finance.fr/comment-ameliorer-la-gestion-financiere-de-son-entreprise/',
#  'https://www.s-finance.fr/debuter-dans-le-trading-zoom-sur-le-trading-social/',
#  'https://www.s-finance.fr/comment-optimiser-son-budget-en-periode-de-crise-grace-au-rachat-de-credit/',
#  'https://www.s-finance.fr/quel-est-le-role-dun-courtier-en-assurances/',
#  'https://www.s-finance.fr/choisir-le-bon-cabinet-comptable-pour-votre-entreprise-en-region-parisienne/',
#  'https://www.s-finance.fr/comment-le-libelle-de-ladresse-influence-votre-gestion-financiere/',
#  'https://www.s-finance.fr/comprendre-limportance-de-votre-numero-dassurance-maladie/',
#  'https://www.s-finance.fr/demystifier-le-plan-comptable-general-une-exploration-approfondie/',
#  'https://www.s-finance.fr/comment-optimiser-votre-experience-avec-le-compte-en-ligne-credit-agricole/',
#  'https://www.s-finance.fr/comprendre-levolution-des-cours-de-la-bourse-un-regard-approfondi/',
#  'https://www.s-finance.fr/astucieux-moyens-pour-arrondir-ses-fins-de-mois-en-teletravail/',
#  'https://www.s-finance.fr/optimisez-votre-experience-bancaire-avec-cyberplus-de-la-banque-populaire-astuces-et-conseils/',
#  'https://www.s-finance.fr/maximiser-votre-retraite-apres-une-longue-carriere-strategies-et-conseils-pratiques/',
#  'https://www.s-finance.fr/comment-savoir-que-vous-avez-droit-a-une-pension-de-reversion/',
#  'https://www.s-finance.fr/investir-dans-le-respect-des-regles-de-conformite-comment-philippe-germain-integre-la-reglementation-de-lamf-en-matiere-dinvestissements-immobiliers/',
#  'https://www.s-finance.fr/les-comptences-cls-pour-russir-en-finance-en-2024/',
#  'https://www.s-finance.fr/assurance-scooter-50cc-quelles-sont-les-garanties-indispensables/',
#  'https://www.s-finance.fr/quels-sont-les-avantages-dune-assurance-sante-expatrie/',
#  'https://www.s-finance.fr/comprendre-la-specificite-de-la-mutuelle-des-motards-avantages-et-services-exclusifs/',
#  'https://www.s-finance.fr/limportance-de-lassurance-credit-pour-les-entreprises/',
#  'https://www.s-finance.fr/comment-financer-lachat-de-votre-beneteau/',
#  'https://www.s-finance.fr/ladoption-massive-de-la-cryptomonnaie-dans-le-monde/',
#  'https://www.s-finance.fr/comment-se-rapprocher-dun-cabinet-expert-comptable-adapte-aux-besoins-professionnels/',
#  'https://www.s-finance.fr/bhd-plongee-dans-un-concept-obscur-et-fascinant/',
#  'https://www.s-finance.fr/comprendre-les-indicateurs-cles-pour-evaluer-les-performances-des-entreprises-cotees-en-bourse/',
#  'https://www.s-finance.fr/quels-avantages-de-recourir-a-un-courtier-pour-son-pret-immobilier/',
#  'https://www.s-finance.fr/garantie-de-pret-immobilier-quels-sont-les-criteres-avant-de-sengager/',
#  'https://www.s-finance.fr/le-role-des-plateformes-de-trading-en-ligne-dans-la-gestion-financiere-moderne/',
#  'https://www.s-finance.fr/financer-son-vehicule-les-options-a-considerer-pour-un-pret-auto-adapte/',
#  'https://www.s-finance.fr/quest-ce-quun-cabinet-de-fiscalite-indirecte-pour-entreprise/',
#  'https://www.s-finance.fr/comment-trouver-un-partenaire-de-confiance-pour-un-rachat-dor-a-paris/',
#  'https://www.s-finance.fr/maitrisez-le-calcul-de-la-tva-explications-et-astuces-pratiques/',
#  'https://www.s-finance.fr/reussir-sa-reconversion-professionnelle-le-role-cle-dun-bon-accompagnement/',
#  'https://www.s-finance.fr/comment-fonctionne-une-assurance-pour-un-vehicule-de-collection/',
#  'https://www.s-finance.fr/comment-choisir-son-assurance-auto-criteres-et-astuces/',
#  'https://www.s-finance.fr/le-role-des-galeries-dart-dans-lorganisation-des-evenements-culturels-a-paris/',
#  'https://www.s-finance.fr/3-erreurs-courantes-lorsque-lon-investit-de-largent/',
#  'https://www.s-finance.fr/pourquoi-faire-appel-a-un-conseiller-en-gestion-de-patrimoine-independant/',
#  'https://www.s-finance.fr/3-astuces-pour-reussir-un-investissement-immobilier/',
#  'https://www.s-finance.fr/avantages-de-lepargne-salariale-a-la-poste-types-et-souscription/',
#  'https://www.s-finance.fr/dans-quelle-crypto-monnaie-investir-en-2021/',
#  'https://www.s-finance.fr/les-differences-entre-les-cartes-bancaires-visa-mastercard-et-american-express/',
#  'https://www.s-finance.fr/portage-salarial-independant-prestation-de-service-pour-freelance/',
#  'https://www.s-finance.fr/investir-10-000-euros-pour-senrichir-strategies-efficaces-et-astuces/',
#  'https://www.s-finance.fr/utiliser-un-comparateur-en-ligne-de-mutuelle-sante-pour-faire-le-bon-choix/',
#  'https://www.s-finance.fr/comment-interpreter-les-signaux-forex-et-les-utiliser-pour-optimiser-vos-decisions-de-trading/',
#  'https://www.s-finance.fr/reussir-son-projet-immobilier-a-rennes-grace-a-la-location-accession/',
#  'https://www.s-finance.fr/recours-subrogatoire-en-assurance-maitrisez-les-demarches-et-droits/',
#  'https://www.s-finance.fr/pourquoi-et-comment-bien-comparer-vos-assurances-de-pret/',
#  'https://www.s-finance.fr/indemnite-compensatrice-de-csg-comprendre-son-calcul-et-son-impact/',
#  'https://www.s-finance.fr/pourquoi-opter-pour-louverture-dun-compte-bancaire-en-ligne/',
#  'https://www.s-finance.fr/decouvrez-les-nombreux-atouts-daltaprofits-capitalisation-pour-votre-patrimoine/',
#  'https://www.s-finance.fr/limportance-de-la-diversification-dans-la-gestion-de-son-patrimoine/',
#  'https://www.s-finance.fr/smig-au-maroc-2023-salaire-minimum-evolution-et-impact-economique/',
#  'https://www.s-finance.fr/comment-choisir-sa-mutuelle-sante-en-france-criteres-et-astuces/',
#  'https://www.s-finance.fr/ajuster-sa-couverture-dassurance-moto-en-fonction-de-son-profil/',
#  'https://www.s-finance.fr/organisation-comptable-dentreprise-principes-et-mise-en-place-efficace/',
#  'https://www.s-finance.fr/comprendre-et-naviguer-les-formulaires-du-site-impot-gouv-conseils-pratiques/',
#  'https://www.s-finance.fr/collectivite-comment-assurer-la-securite-aux-abords-des-ecoles/',
#  'https://www.s-finance.fr/le-metaverse-quest-ce-que-cest-et-comment-y-investir/',
#  'https://www.s-finance.fr/les-criteres-a-prendre-en-compte-pour-comparer-les-offres-de-pret-personnel/',
#  'https://www.s-finance.fr/les-differentes-manieres-dinvestir-dans-le-non-cote/',
#  'https://www.s-finance.fr/dation-en-paiement-expliquee-avantages-et-processus-legal/',
#  'https://www.s-finance.fr/faire-construire-sa-maison-a-vitre-un-projet-cle-en-main-avec-un-constructeur-de-confiance/',
#  'https://www.s-finance.fr/optimisez-votre-gestion-financiere-grace-a-un-logiciel-de-pilotage-de-tresorerie/',
#  'https://www.s-finance.fr/comment-choisir-la-meilleure-assurance-responsabilite-civile-pour-une-entreprise/',
#  'https://www.s-finance.fr/maximiser-vos-chances-dobtenir-un-credit-instantane-conseils-et-astuces/',
#  'https://www.s-finance.fr/resiliation-contrat-assurance-maitrisez-larticle-l113-12-du-code/',
#  'https://www.s-finance.fr/comment-investir-dans-le-private-equity-en-2024/',
#  'https://www.s-finance.fr/les-avantages-davoir-une-certification-amf-pour-votre-carriere/',
#  'https://www.s-finance.fr/salaires-en-australie-comprendre-le-marche-de-lemploi-et-la-remuneration/',
#  'https://www.s-finance.fr/comment-fonctionne-le-coefficient-bonus-malus/',
#  'https://www.s-finance.fr/5-conseils-pour-economiser-sur-vos-tarifs-dassurance-credit/',
#  'https://www.s-finance.fr/les-competences-cles-pour-exceller-en-tant-que-manager-et-les-formations-pour-les-acquerir/',
#  'https://www.s-finance.fr/collection-piece-de-2-euros-astuces-et-idees-pour-les-valoriser/',
#  'https://www.s-finance.fr/retraite-avec-1500-euros-de-salaire-montant-et-optimisation-des-pensions/',
#  'https://www.s-finance.fr/assurance-logement-comment-trouver-la-formule-qui-vous-convient/',
#  'https://www.s-finance.fr/les-avantages-detudier-la-finance-dans-une-ecole-de-commerce/',
#  'https://www.s-finance.fr/parrainer-un-orphelin-dans-le-cadre-du-plan-rse-de-sa-societe/',
#  'https://www.s-finance.fr/calcul-tva-sur-ttc-methode-precise-pour-arrondir-la-taxe-efficacement/',
#  'https://www.s-finance.fr/pourquoi-les-professionnels-devraient-faire-creer-des-cartes-de-visites-adequates/',
#  'https://www.s-finance.fr/lep-epargne-avantages-et-fonctionnement-du-livret-depargne-populaire/',
#  'https://www.s-finance.fr/conseils-pour-obtenir-un-pret-rapide-sans-tracas/',
#  'https://www.s-finance.fr/comprendre-le-revenu-primaire-calcul-et-definition-essentiels/',
#  'https://www.s-finance.fr/quelles-solutions-pour-financer-lachat-dun-bateau/',
#  'https://www.s-finance.fr/romy-investir-dans-lor-tout-ce-que-vous-devez-savoir/',
#  'https://www.s-finance.fr/la-formation-danglais-en-entreprise-opportunites-professionnelles-dans-le-secteur-de-la-finance/',
#  'https://www.s-finance.fr/tout-comprendre-sur-les-cartes-bancaires-pour-les-mineurs/',
#  'https://www.s-finance.fr/devenir-riche-rapidement-strategies-efficaces-et-astuces-pratiques/',
#  'https://www.s-finance.fr/tout-savoir-sur-le-plan-depargne-retraite-individuel/',
#  'https://www.s-finance.fr/assurance-pret-immobilier-quelle-couverture-choisir/',
#  'https://www.s-finance.fr/taux-fixe-ou-taux-variable-choisissez-des-maintenant-le-taux-immobilier-qui-vous-convient/',
#  'https://www.s-finance.fr/strategies-financieres-et-gestion-des-risques-un-equilibre-indispensable/',
#  'https://www.s-finance.fr/quels-sont-les-avantages-dutiliser-un-logiciel-de-gestion-dassurance/',
#  'https://www.s-finance.fr/indemnisation-pour-souffrances-endurees-montants-et-jurisprudence/',
#  'https://www.s-finance.fr/rachat-de-credit-et-liberte-financiere-les-liens-indissociables/',
#  'https://www.s-finance.fr/les-avantages-dinvestir-dans-un-programme-neuf-immobilier/',
#  'https://www.s-finance.fr/limites-des-paiements-en-especes-comprendre-les-regles-et-restrictions/',
#  'https://www.s-finance.fr/changer-des-francs-suisses-astuces-et-meilleur-timing-pour-optimiser-votre-change/',
#  'https://www.s-finance.fr/comment-souscrire-une-assurance-vie/',
#  'https://www.s-finance.fr/la-mutuelle-pour-les-animaux-un-bon-moyen-de-faire-des-economies/',
#  'https://www.s-finance.fr/les-regles-fiscales-a-connaitre-pour-les-dons-aux-associations-guide-pratique/',
#  'https://www.s-finance.fr/fan-de-crypto-vous-allez-adorer-ces-jeux/',
#  'https://www.s-finance.fr/comment-se-passe-la-vente-ou-lachat-de-lingots-dor/',
#  'https://www.s-finance.fr/comment-les-nouvelles-banques-changent-elles-la-donne/',
#  'https://www.s-finance.fr/comment-investir-en-ligne-facilement-des-conseils-pratiques-pour-les-debutants/',
#  'https://www.s-finance.fr/cryptomonnaies-decouvrez-ce-quil-faut-savoir-avant-dinvestir/',
#  'https://www.s-finance.fr/les-dons-aux-associations-et-les-avantages-fiscaux-qui-en-decoulent/',
#  'https://www.s-finance.fr/les-innovations-financieres-et-technologiques-un-moteur-de-transformation-pour-les-industries/',
#  'https://www.s-finance.fr/le-cabinet-comptable-a-nantes-vous-aide-pour-plusieurs-taches/',
#  'https://www.s-finance.fr/tout-savoir-sur-le-fonctionnement-dune-scpi-de-sante/',
#  'https://www.s-finance.fr/les-meilleures-solutions-pour-reduire-son-impot-sur-le-revenu-en-2024/',
#  'https://www.s-finance.fr/le-bitcoin-depasse-les-40-000-dollars-faut-il-investir-en-ce-moment/',
#  'https://www.s-finance.fr/comprendre-les-avantages-et-les-risques-de-linvestissement-boursier/',
#  'https://www.s-finance.fr/comment-optimiser-vos-finances-en-tant-que-celibataire/',
#  'https://www.s-finance.fr/comment-bien-gerer-vos-finances-personnelles-en-5-etapes-cles/',
#  'https://www.s-finance.fr/decouvrir-les-differents-types-de-fraudes-documentaires-en-ligne-ou-non/',
#  'https://www.s-finance.fr/pourquoi-utiliser-un-logiciel-de-recouvrement-pour-gerer-vos-impayes/',
#  'https://www.s-finance.fr/quelles-demarches-pour-resilier-votre-assurance-habitation-avant-de-changer-de-logement/',
#  'https://www.s-finance.fr/les-avantages-du-regroupement-de-credit-pour-les-seniors/',
#  'https://www.s-finance.fr/quelques-conseils-en-ce-qui-concerne-lachat-de-cryptomonnaies/',
#  'https://www.s-finance.fr/comment-un-courtier-en-assurance-pret-peut-vous-aider-dans-le-processus-dachat-immobilier/',
#  'https://www.s-finance.fr/est-il-interessant-davoir-une-assurance-vie-au-luxembourg/',
#  'https://www.s-finance.fr/comprendre-ce-quest-une-assurance-emprunteur/',
#  'https://www.s-finance.fr/per-tout-savoir-sur-le-meilleur-placement-retraite/',
#  'https://www.s-finance.fr/quest-ce-qui-fait-un-bon-plan-de-trading-ces-etapes-vous-manquent-elles/',
#  'https://www.s-finance.fr/fiscaliste-ou-comptable-qui-devrez-vous-choisir-pour-la-gestion-financiere-de-votre-entreprise/',
#  'https://www.s-finance.fr/les-changements-actuels-et-futurs-dans-le-secteur-bancaire/',
#  'https://www.s-finance.fr/les-erreurs-a-eviter-lors-de-la-planification-du-budget-de-votre-cse/',
#  'https://www.s-finance.fr/la-loi-lemoine-et-ses-consequences-sur-lassurance-emprunteur/',
#  'https://www.s-finance.fr/la-renovation-en-tant-que-partie-de-linvestissement-immobilier/',
#  'https://www.s-finance.fr/le-role-cle-des-plateformes-de-trading-dans-la-gestion-efficace-de-vos-finances/',
#  'https://www.s-finance.fr/comment-realiser-une-simulation-de-portage-salarial-efficace-avec-excel/',
#  'https://www.s-finance.fr/quelle-crypto-va-exploser-en-2023/',
#  'https://www.s-finance.fr/matrice-raci-quest-ce-que-cest/',
#  'https://www.s-finance.fr/quelles-sont-les-activites-les-plus-rentables/',
#  'https://www.s-finance.fr/pourquoi-faire-appel-a-une-fiduciaire/',
#  'https://www.s-finance.fr/fiabilite-dun-investissement-en-cryptomonnaies-evaluation-des-facteurs-cles-pour-les-investisseurs/',
#  'https://www.s-finance.fr/quels-sont-les-avantages-de-lassurance-extra-scolaire/',
#  'https://www.s-finance.fr/comment-pourquoi-et-ou-investir-ses-premiers-euros/',
#  'https://www.s-finance.fr/quelles-sont-les-charges-financieres-en-entreprise/',
#  'https://www.s-finance.fr/quelle-est-la-fiscalite-du-marchand-de-biens/',
#  'https://www.s-finance.fr/ouverture-dun-compte-bancaire-au-credit-agricole-les-etapes-a-suivre/',
#  'https://www.s-finance.fr/banque-casino-mon-compte/',
#  'https://www.s-finance.fr/quel-pays-sans-tva/',
#  'https://www.s-finance.fr/les-supers-livrets-une-option-depargne-attrayante/',
#  'https://www.s-finance.fr/comment-bien-choisir-le-logiciel-de-caisse-pour-votre-epicerie/',
#  'https://www.s-finance.fr/sur-quels-criteres-choisir-une-offre-de-telephonie-mobile-professionnelle/',
#  'https://www.s-finance.fr/optimisez-la-collaboration-en-entreprise-grace-a-la-matrice-raci/',
#  'https://www.s-finance.fr/les-avantages-et-les-defis-de-la-decentralisation-dans-le-monde-du-web-3-0/',
#  'https://www.s-finance.fr/pourquoi-choisir-dinvestir-dans-un-appartement-en-haute-savoie/',
#  'https://www.s-finance.fr/tous-nos-conseils-pour-bien-comparer-les-devis-dassurance-auto/',
#  'https://www.s-finance.fr/assurance-que-faut-il-savoir/',
#  'https://www.s-finance.fr/quelles-informations-trouve-t-on-sur-les-blogs-de-marketing-digital/',
#  'https://www.s-finance.fr/entreprise-quels-sont-les-impots-a-payer/',
#  'https://www.s-finance.fr/comment-obtenir-un-pret-immobilier-avantageux-grace-a-ces-astuces-de-negociation/',
#  'https://www.s-finance.fr/comment-les-serveurs-vocaux-peuvent-ameliorer-la-satisfaction-des-clients/',
#  'https://www.s-finance.fr/assurance-habitation-en-ligne-une-bonne-idee/',
#  'https://www.s-finance.fr/cinq-idees-pour-arrondir-les-fins-de-mois-sans-quitter-son-domicile/',
#  'https://www.s-finance.fr/la-flexibilite-professionnelle-sadapter-au-marche-de-lemploi-en-mutation/',
#  'https://www.s-finance.fr/assurance-vie-francaise-vs-assurance-vie-luxembourgeoise/',
#  'https://www.s-finance.fr/pensez-a-votre-retraite-grace-au-perp/',
#  'https://www.s-finance.fr/quelques-endroits-pour-organiser-un-seminaire-reussi-a-lyon/',
#  'https://www.s-finance.fr/comment-bien-choisir-son-assurance-quand-on-est-cardiologue/',
#  'https://www.s-finance.fr/le-rachat-de-credit-a-la-consommation-une-solution-pour-regrouper-ses-dettes/',
#  'https://www.s-finance.fr/quelles-sont-les-actions-value/',
#  'https://www.s-finance.fr/pourquoi-faire-recours-a-un-expert-en-objets-publicitaires-et-goodies-personnalisables/',
#  'https://www.s-finance.fr/quelles-questions-faut-il-se-poser-pour-trouver-la-meilleure-assurance-auto-adaptee-a-vos-besoins/',
#  'https://www.s-finance.fr/defiscalisez-vos-loyers-en-location-meublee-lmnp-mode-demploi/',
#  'https://www.s-finance.fr/le-courtage-en-placements-financiers-un-atout-pour-votre-securite-financiere/',
#  'https://www.s-finance.fr/sur-quel-document-faut-il-apposer-un-tampon-dentreprise/',
#  'https://www.s-finance.fr/pourquoi-faire-le-choix-de-votre-sol-aupres-dun-site-specialise/',
#  'https://www.s-finance.fr/projet-immobilier-pourquoi-faire-appel-a-des-professionnels/',
#  'https://www.s-finance.fr/assurance-emprunteur-guide-comparatif-pour-economiser-sur-votre-assurance-de-pret/',
#  'https://www.s-finance.fr/les-particularites-de-lassurance-credit-immobilier-pour-les-jeunes-emprunteurs/',
#  'https://www.s-finance.fr/comment-bien-assurer-vos-biens-pendant-votre-demenagement-avec-matmut/',
#  'https://www.s-finance.fr/les-cles-dune-assurance-logement-rapide-et-sans-tracas/',
#  'https://www.s-finance.fr/resiliation-dassurance-auto-chez-groupama-ce-que-vous-devez-savoir-3/',
#  'https://www.s-finance.fr/resiliation-dassurance-auto-chez-groupama-ce-que-vous-devez-savoir-2/',
#  'https://www.s-finance.fr/resiliation-dassurance-auto-chez-groupama-ce-que-vous-devez-savoir/',
#  'https://www.s-finance.fr/assurance-auto-professionnelle-comment-evaluer-vos-besoins-et-choisir-la-bonne-formule/',
#  'https://www.s-finance.fr/le-secret-des-franchises-dassurance-auto-quels-sont-les-prix-pratiques/',
#  'https://www.s-finance.fr/investissement-dans-limmobilier-ancien-les-points-de-vigilance/',
#  'https://www.s-finance.fr/comprendre-la-caution-solidaire/',
#  'https://www.s-finance.fr/micro-credit-une-alternative-aux-credits-des-banques/',
#  'https://www.s-finance.fr/les-priorites-pour-les-directions-financieres-en-2023/',
#  'https://www.s-finance.fr/louer-sa-residence-secondaire-comment-optimiser-vos-revenus/',
#  'https://www.s-finance.fr/comment-determiner-le-moment-optimal-pour-activer-son-stop-en-bourse/',
#  'https://www.s-finance.fr/pourquoi-faire-une-demande-de-credit-en-ligne/',
#  'https://www.s-finance.fr/pourquoi-utiliser-un-comparateur-de-credit/',
#  'https://www.s-finance.fr/pourquoi-devriez-vous-envisager-dacheter-de-lor/',
#  'https://www.s-finance.fr/acheter-a-lille-les-meilleurs-quartiers-ou-habiter/',
#  'https://www.s-finance.fr/comment-choisir-son-cabinet-dexpertise-comptable/',
#  'https://www.s-finance.fr/quels-sont-les-frais-annexes-a-prendre-en-compte-dans-un-credit-relais/',
#  'https://www.s-finance.fr/rentabilite-et-location-de-voiture-les-tendances-du-marche-a-surveiller/',
#  'https://www.s-finance.fr/les-meilleures-techniques-pour-economiser-sur-vos-achats-en-ligne/',
#  'https://www.s-finance.fr/comment-choisir-un-courtier-immobilier-a-bordeaux-les-criteres-a-prendre-en-compte/',
#  'https://www.s-finance.fr/zoom-sur-la-loi-pinel/',
#  'https://www.s-finance.fr/comment-obtenir-un-micro-credit-en-ligne/',
#  'https://www.s-finance.fr/comment-resilier-son-assurance-vie-chez-le-credit-agricole/',
#  'https://www.s-finance.fr/5-raisons-de-faire-confiance-a-une-banque-en-ligne/',
#  'https://www.s-finance.fr/augmenter-la-visibilite-de-sa-marque-les-meilleurs-conseils/',
#  'https://www.s-finance.fr/comment-les-mediateurs-agissent-ils-dans-les-litiges-avec-direct-assurance-auto/',
#  'https://www.s-finance.fr/comment-resilier-son-contrat-dassurance-auto-chez-lelynx/',
#  'https://www.s-finance.fr/devis-assurance-moto-pourquoi-choisir-les-offres-groupama/',
#  'https://www.s-finance.fr/annuler-votre-assurance-auto-axa-les-etapes-a-suivre-pas-a-pas/',
#  'https://www.s-finance.fr/comment-faire-baisser-le-cout-de-votre-assurance-habitation-en-securisant-votre-logement/',
#  'https://www.s-finance.fr/les-garanties-essentielles-dune-assurance-habitation-conservation-pour-la-conservation-de-votre-habitat/',
#  'https://www.s-finance.fr/souscrire-une-assurance-vie-a-letranger-comment-ca-marche/',
#  'https://www.s-finance.fr/pourquoi-creer-un-patrimoine-immobilier/',
#  'https://www.s-finance.fr/credit-a-la-consommation-tout-ce-que-vous-devez-connaitre-avant-de-vous-lancer/',
#  'https://www.s-finance.fr/comment-trouver-le-credit-auto-adapte-a-vos-besoins-en-2020/',
#  'https://www.s-finance.fr/quest-ce-quun-courtier-en-pret-professionnel/',
#  'https://www.s-finance.fr/comment-realiser-un-bon-investissement/',
#  'https://www.s-finance.fr/pourquoi-devriez-vous-suivre-des-bogs-sur-les-cryptomonnaies/',
#  'https://www.s-finance.fr/comment-choisir-sa-mutuelle-sante/',
#  'https://www.s-finance.fr/investir-pour-lavenir-les-choix-de-placement-financier-en-2023/',
#  'https://www.s-finance.fr/tout-comprendre-sur-lassurance-habitation/',
#  'https://www.s-finance.fr/resiliation-dassurance-voiture-tout-ce-que-vous-devez-savoir-chez-groupama/',
#  'https://www.s-finance.fr/le-cashback-peut-etre-solidaire/',
#  'https://www.s-finance.fr/mieux-comprendre-le-pret-hypothecaire/',
#  'https://www.s-finance.fr/tout-savoir-sur-lassurance-emprunteur/',
#  'https://www.s-finance.fr/les-assurances-auto-pour-les-conducteurs-novices-comment-sy-retrouver/',
#  'https://www.s-finance.fr/que-fautil-prendre-en-compte-pour-bien-choisir-son-assurance-auto/',
#  'https://www.s-finance.fr/le-3eme-pilier-quest-ce-que-cest/',
#  'https://www.s-finance.fr/quest-ce-qui-fait-fluctuer-le-cours-du-bitcoin/',
#  'https://www.s-finance.fr/comment-sappelle-la-bourse-de-londres/',
#  'https://www.s-finance.fr/quand-preparer-sa-retraite/',
#  'https://www.s-finance.fr/tout-savoir-sur-lapi-de-paiement-en-ligne/',
#  'https://www.s-finance.fr/les-avantages-du-portage-salarial-et-comment-loptimiser-avec-excel/',
#  'https://www.s-finance.fr/les-etapes-indispensables-pour-simuler-votre-portage-salarial-sur-excel/',
#  'https://www.s-finance.fr/comment-relancer-une-facture-impayee/',
#  'https://www.s-finance.fr/assurance-auto-pourquoi-choisir-une-assurance-au-kilometre/',
#  'https://www.s-finance.fr/comment-faire-une-demande-de-pret-personnel-en-belgique/',
#  'https://www.s-finance.fr/tout-savoir-sur-le-logiciel-de-paie/',
#  'https://www.s-finance.fr/entreprises-pourquoi-opter-pour-la-solution-de-clearnox/',
#  'https://www.s-finance.fr/assurance-moto-bnp-quelles-sont-les-options-disponibles/',
#  'https://www.s-finance.fr/programme-immobilier-neuf-les-cles-pour-reussir-son-investissement/',
#  'https://www.s-finance.fr/10-raisons-pour-lesquelles-votre-petite-entreprise-a-besoin-dun-expert-comptable/',
#  'https://www.s-finance.fr/les-specificites-de-lassurance-auto-les-cles-pour-bien-comprendre/',
#  'https://www.s-finance.fr/les-bonnes-raisons-dinvestir-dans-un-contrat-dassurance-vie-en-2018/',
#  'https://www.s-finance.fr/comment-choisir-votre-financement-pour-un-achat/',
#  'https://www.s-finance.fr/5-choses-que-vous-devez-savoir-absolument-de-limmobilier-commercial/',
#  'https://www.s-finance.fr/quels-sont-les-avantages-de-lassurance-vie/',
#  'https://www.s-finance.fr/les-meilleures-astuces-pour-generer-facilement-de-largent-grace-aux-crypto-monnaies/',
#  'https://www.s-finance.fr/comment-miner-la-crypto-monnaie-la-plus-rentable-2/',
#  'https://www.s-finance.fr/pourquoi-souscrire-une-assurance-vie-au-luxembourg/',
#  'https://www.s-finance.fr/guide-sur-le-rachat-de-credits/',
#  'https://www.s-finance.fr/faut-il-passer-par-une-agence-pour-vendre-sa-maison-rapidement/',
#  'https://www.s-finance.fr/quel-budget-pour-investir-en-bourse/',
#  'https://www.s-finance.fr/lisolation-des-combles-un-investissement-rentable-pour-votre-maison/',
#  'https://www.s-finance.fr/comment-realiser-une-simulation-de-portage-salarial-en-ligne-efficace/',
#  'https://www.s-finance.fr/tout-ce-que-vous-devez-savoir-sur-la-simulation-de-portage-salarial-en-ligne/',
#  'https://www.s-finance.fr/les-avantages-de-la-simulation-de-portage-salarial-en-ligne-pour-les-freelances/',
#  'https://www.s-finance.fr/les-poids-lourds-de-la-bourse-de-paris-decryptage-du-cac-40/',
#  'https://www.s-finance.fr/comprendre-les-frais-financiers-en-entreprise-comment-optimiser-sa-gestion-budgetaire/',
#  'https://www.s-finance.fr/assurance-moto-comment-trouver-la-formule-ideale-qui-correspond-a-son-budget/',
#  'https://www.s-finance.fr/les-erreurs-a-eviter-lors-de-la-recherche-dun-pret-auto-a-faible-taux/',
#  'https://www.s-finance.fr/groupama-une-assurance-auto-pour-tous-les-conducteurs/',
#  'https://www.s-finance.fr/amaguiz-lassurance-auto-a-la-carte/',
#  'https://www.s-finance.fr/les-astuces-pour-faire-baisser-le-prix-de-lassurance-auto-pour-un-jeune-conducteur/',
#  'https://www.s-finance.fr/les-conseils-pratiques-pour-bien-gerer-son-assurance-auto-jeune-conducteur-avec-laide-de-ses-parents/',
#  'https://www.s-finance.fr/pourquoi-lassurance-au-kilometre-est-elle-une-solution-pour-les-conducteurs-occasionnels-les-forums-en-parlent/',
#  'https://www.s-finance.fr/trouver-lassurance-auto-qui-vous-convient-avec-loffre-au-kilometre-de-maaf/',
#  'https://www.s-finance.fr/que-savoir-sur-la-gestion-de-patrimoine-pour-devenir-riche-sur-le-long-terme/',
#  'https://www.s-finance.fr/mieux-comprendre-lassurance-decennale-en-4-points-cles/',
#  'https://www.s-finance.fr/credit-immobilier-ou-credit-a-la-consommation/',
#  'https://www.s-finance.fr/les-details-importants-a-connaitre-avant-de-resilier-votre-assurance-habitation-chez-direct-assurance/',
#  'https://www.s-finance.fr/tout-savoir-sur-la-declaration-de-revenus-en-2023/',
#  'https://www.s-finance.fr/comment-avoir-une-carte-bancaire-quand-on-est-mineur/',
#  'https://www.s-finance.fr/jeune-conducteur-quel-type-dassurance-choisir/',
#  'https://www.s-finance.fr/pourquoi-avoir-un-credit-autorise/',
#  'https://www.s-finance.fr/comment-stocker-vos-cryptomonnaies-en-toute-securite/',
#  'https://www.s-finance.fr/le-placement-immobilier-via-le-scpi-ce-quil-faut-savoir/',
#  'https://www.s-finance.fr/choisir-la-meilleure-solution-de-paiement-en-ligne-pour-votre-entreprise-guide-complet/',
#  'https://www.s-finance.fr/augmenter-la-visibilite-de-sa-marque-6-astuces/',
#  'https://www.s-finance.fr/3-actions-a-mener-avant-dinvestir-en-bourse/',
#  'https://www.s-finance.fr/pret-pour-lachat-dun-vehicule-pourquoi-faire-une-simulation-en-ligne/',
#  'https://www.s-finance.fr/quel-est-le-projet-de-la-nft-katmonstarz/',
#  'https://www.s-finance.fr/plateforme-de-trading-quest-ce-que-cest/',
#  'https://www.s-finance.fr/pourquoi-est-ce-obligatoire-dassurer-votre-trottinette-electrique/',
#  'https://www.s-finance.fr/dans-quelles-cryptomonnaies-investir-en-2023/',
#  'https://www.s-finance.fr/les-avantages-de-souscrire-une-assurance-auto-maaf-avec-un-delai-de-retractation/',
#  'https://www.s-finance.fr/demenagement-optez-pour-laccompagnement-matmut-pour-plus-de-tranquillite/',
#  'https://www.s-finance.fr/tout-ce-que-vous-devez-savoir-sur-la-delegation-dassurance-emprunteur/',
#  'https://www.s-finance.fr/financer-un-projet-immobilier-quelles-sont-les-solutions-possibles/',
#  'https://www.s-finance.fr/tout-savoir-sur-la-signature-en-ligne/',
#  'https://www.s-finance.fr/comment-bien-negocier-son-contrat-de-portage-salarial/',
#  'https://www.s-finance.fr/les-erreurs-courantes-a-eviter-lors-de-la-location-de-camion-en-aller-simple-pour-votre-demenagement/',
#  'https://www.s-finance.fr/quelles-sont-les-informations-necessaires-a-avoir-sur-les-nft/',
#  'https://www.s-finance.fr/incendie-criminel-les-meilleures-assurances-pour-se-proteger/',
#  'https://www.s-finance.fr/pourquoi-se-lancer-dans-linvestissement-locatif/',
#  'https://www.s-finance.fr/les-outils-de-reporting-les-plus-performants-pour-un-logiciel-comptable/',
#  'https://www.s-finance.fr/qui-peut-avoir-droit-a-un-rachat-de-credits/',
#  'https://www.s-finance.fr/rachat-de-credits-comment-bien-choisir-votre-partenaire-financier/',
#  'https://www.s-finance.fr/quelle-procedure-entreprendre-pour-recuperer-des-factures/',
#  'https://www.s-finance.fr/3-bonnes-raisons-dacheter-une-voiture-doccasion/',
# ...
#  'https://www.s-finance.fr/quel-interet-pour-une-entreprise-de-faire-financer-son-materiel/',
#  'https://www.s-finance.fr/comment-trouver-de-bonnes-ventes-aux-encheres/',
#  'https://www.s-finance.fr/pourquoi-suivre-une-formation-avant-de-se-lancer-en-trading/',
#  'https://www.s-finance.fr/existe-t-il-des-risques-a-la-diffusion-du-numero-iban/',
#  'https://www.s-finance.fr/sasu-attention-aux-pieges/',
#  'https://www.s-finance.fr/60000-euros-le-montant-maximum-pour-emprunter-sans-justifier-son-salaire/',
#  'https://www.s-finance.fr/pourquoi-choisir-lassurance-logement-etudiant-maif/',
#  'https://www.s-finance.fr/quels-sont-les-criteres-a-considerer-lors-dun-rachat-dentreprise/',
#  'https://www.s-finance.fr/construire-un-patrimoine-a-travers-les-societes-dinvestissement-familiales/',
#  'https://www.s-finance.fr/les-avantages-fiscaux-offerts-a-ceux-qui-investissent-dans-limmobilier/',
#  'https://www.s-finance.fr/comment-determiner-le-meilleur-taux-dinteret-pour-votre-credit/',
#  'https://www.s-finance.fr/les-avantages-et-les-inconvenients-des-comptes-bancaires-en-ligne/',
#  'https://www.s-finance.fr/strategies-de-retraite-pour-les-investisseurs-a-court-terme/',
#  'https://www.s-finance.fr/comment-reduire-les-couts-financiers-dans-une-entreprise/',
#  'https://www.s-finance.fr/les-avantages-de-la-carte-de-credit-en-ligne/',
#  'https://www.s-finance.fr/le-regroupement-de-credits-une-solution-pour-sortir-de-lendettement/',
#  'https://www.s-finance.fr/le-marche-de-courchevel-en-2019/',
#  'https://www.s-finance.fr/rachat-de-son-credit-immobilier-3-points-importants-a-savoir/',
#  'https://www.s-finance.fr/comment-rediger-une-lettre-de-motivation-efficace-pour-une-demande-de-financement/',
#  'https://www.s-finance.fr/le-guide-des-prix-de-lelectricite-en-france/',
#  'https://www.s-finance.fr/pourquoi-les-scpi-sont-elles-toujours-aussi-interessantes-en-2023/',
#  'https://www.s-finance.fr/assurance-logement-en-belgique-les-meilleures-offres/',
#  'https://www.s-finance.fr/lassurance-professionnelle-un-must-have-pour-tous-les-travailleurs/',
#  'https://www.s-finance.fr/avantages-de-sinstaller-en-suisse/',
#  'https://www.s-finance.fr/assurance-habitation-les-astuces-pour-payer-moins-cher/',
#  'https://www.s-finance.fr/pourquoi-choisir-un-per/',
#  'https://www.s-finance.fr/5-astuces-pour-obtenir-le-meilleur-taux-de-credit/',
#  'https://www.s-finance.fr/comprendre-les-cryptomonnaies-et-leurs-implications-sur-leconomie/',
#  'https://www.s-finance.fr/quelle-est-la-fiscalite-de-lassurance-vie-apres-8-ans/',
#  'https://www.s-finance.fr/les-secrets-de-la-finance-pour-les-investisseurs/',
#  'https://www.s-finance.fr/les-meilleurs-endroits-pour-investir-son-argent-en-2020/',
#  'https://www.s-finance.fr/analyse-des-principales-tendances-de-la-technologie-blockchain-et-des-crypto-monnaies/',
#  'https://www.s-finance.fr/quel-est-le-role-dun-trader-en-bourse/',
#  'https://www.s-finance.fr/les-etf-la-revolution-du-trading-a-portee-de-tous/',
#  'https://www.s-finance.fr/marches-financiers-zoom-sur-le-paysage-francais/',
#  'https://www.s-finance.fr/creer-votre-franchise-en-2023/',
#  'https://www.s-finance.fr/pourquoi-avoir-recours-a-une-assurance-emprunteur/',
#  'https://www.s-finance.fr/pourquoi-investir-dans-le-secteur-immobilier-avec-la-societe-remake/',
#  'https://www.s-finance.fr/quels-sont-les-avantages-du-paiement-en-plusieurs-fois/',
#  'https://www.s-finance.fr/tout-ce-que-vous-devez-savoir-sur-la-cooperative-emrys-la-carte/',
#  'https://www.s-finance.fr/achat-dune-maison-les-7-precautions-a-prendre/',
#  'https://www.s-finance.fr/pourquoi-faire-appel-a-une-entreprise-specialiste-du-recouvrement-client/',
#  'https://www.s-finance.fr/comment-choisir-un-compte-titres/',
#  'https://www.s-finance.fr/des-solutions-innovantes-pour-la-prevoyance-en-suisse/',
#  'https://www.s-finance.fr/comment-comparer-les-offres-dassurance-auto/',
#  'https://www.s-finance.fr/comment-une-assurance-credit-peut-elle-profiter-a-votre-entreprise/',
#  'https://www.s-finance.fr/assurance-credit-100-ou-50-quel-est-le-meilleur-choix-pour-vous/',
#  'https://www.s-finance.fr/entreprise-comment-choisir-un-journal-habilite-pour-publier-votre-annonce-legale/',
#  'https://www.s-finance.fr/les-algorithmes-de-trading-est-ce-vraiment-efficace/',
#  'https://www.s-finance.fr/les-avantages-dun-courtier-en-ligne/',
#  'https://www.s-finance.fr/la-resiliation-direct-assurance-en-cas-de-resiliation-du-contrat/',
#  'https://www.s-finance.fr/taux-reels-negatifs-une-situation-exceptionnelle-pour-sendetter/',
#  'https://www.s-finance.fr/credits-et-prets-bancaires-comment-choisir-la-meilleure-offre-pour-vous/',
#  'https://www.s-finance.fr/comment-bien-planifier-le-renouvellement-de-votre-hypotheque/',
#  'https://www.s-finance.fr/pret-viager-hypothecaire-une-aubaine-si-vous-etes-eligible/',
#  'https://www.s-finance.fr/dif-cpf-a-quoi-sert-il-vraiment/',
#  'https://www.s-finance.fr/pourquoi-souscrire-une-assurance-tous-risques/',
#  'https://www.s-finance.fr/factures-etes-vous-oblige-de-passer-au-digital/',
#  'https://www.s-finance.fr/les-avantages-de-souscrire-une-assurance-tous-risques/',
#  'https://www.s-finance.fr/expatries-quels-risques-pour-votre-sante/',
#  'https://www.s-finance.fr/comment-contester-une-facture-denergie/',
#  'https://www.s-finance.fr/assurance-habitation-comment-eviter-les-mauvaises-surprises/',
#  'https://www.s-finance.fr/la-fiscalite-des-sorties-en-capital-en-france/',
#  'https://www.s-finance.fr/comprendre-les-principes-de-base-de-lassurance/',
#  'https://www.s-finance.fr/investir-dans-les-metaux/',
#  'https://www.s-finance.fr/tout-savoir-sur-le-service-client-telephonique-dune-banque-en-ligne/',
#  'https://www.s-finance.fr/10-choses-a-savoir-sur-les-actualites-crypto/',
#  'https://www.s-finance.fr/pourquoi-vous-faire-accompagner-dexperts-pour-votre-recherche-de-logement/',
#  'https://www.s-finance.fr/crowdfunding-comment-se-lancer-sans-risque/',
#  'https://www.s-finance.fr/les-avantages-de-travailler-avec-un-courtier-hypothecaire/',
#  'https://www.s-finance.fr/fiscalite-et-societes-implantees-a-letranger/',
#  'https://www.s-finance.fr/comment-un-courtier-en-hypotheque-peut-il-vous-aider/',
#  'https://www.s-finance.fr/assurance-pret-immobilier-pourquoi-faut-il-absolument-faire-une-simulation/',
#  'https://www.s-finance.fr/comment-comptabiliser-un-paiement-par-carte-de-credit/',
#  'https://www.s-finance.fr/les-multiples-raisons-dinvestir-dans-le-domaine-immobilier-a-toulouse/',
#  'https://www.s-finance.fr/situation-dendettement-les-raisons-de-preferer-la-proposition-de-consommateur/',
#  'https://www.s-finance.fr/la-mutuelle-vous-demande-votre-numero-de-contrat-pourquoi/',
#  'https://www.s-finance.fr/la-loi-girardin-industriel-ces-principes-et-comment-lappliquer/',
#  'https://www.s-finance.fr/pourquoi-devriez-vous-faire-evaluer-votre-appartement-avant-de-le-vendre/',
#  'https://www.s-finance.fr/pourquoi-les-rendements-des-scpi-baissent/',
#  'https://www.s-finance.fr/comment-se-passe-le-rachat-de-credit/',
#  'https://www.s-finance.fr/limportance-davoir-une-agence-immobiliere-la-vente-de-sa-maison/',
#  'https://www.s-finance.fr/quels-prerequis-pour-une-formation-de-gestionnaire-de-paie/',
#  'https://www.s-finance.fr/comment-mieux-gerer-son-patrimoine/',
#  'https://www.s-finance.fr/investissement-comment-sen-sortir-dans-le-contexte-actuel/',
#  'https://www.s-finance.fr/comment-trouver-un-logement-temporaire-a-paris/',
#  'https://www.s-finance.fr/naturalisation-et-taxes-liees-prenez-un-avocat-conseil/',
#  'https://www.s-finance.fr/quelle-solution-pour-une-meilleure-gestion-de-tresorerie-dans-une-entreprise/',
#  'https://www.s-finance.fr/comment-ouvrir-un-compte-bancaire-professionnel-en-ligne/',
#  'https://www.s-finance.fr/ethereum-comment-connaitre-son-cours/',
#  'https://www.s-finance.fr/comment-gagner-du-temps-dans-la-gestion-de-sinistre-auto/',
#  'https://www.s-finance.fr/oeuvres-dart-limportance-de-les-assurer/',
#  'https://www.s-finance.fr/artisan-peintre-comment-trouver-des-chantiers-de-peinture/',
#  'https://www.s-finance.fr/comment-faire-des-economies-au-quotidien/',
#  'https://www.s-finance.fr/avant-de-commencer-a-trader-avec-metatrader-4-il-est-important-de-comprendre-comment-linterface-de-lapplication-fonctionne/',
#  'https://www.s-finance.fr/quels-impots-payez-vous-exactement-a-dubai/',
#  'https://www.s-finance.fr/le-trading-cest-quoi-exactement/',
#  'https://www.s-finance.fr/quels-sont-les-avantages-de-lassurance-maladie/',
#  'https://www.s-finance.fr/limportance-de-la-gestion-des-risques-pour-les-entreprises/',
#  'https://www.s-finance.fr/pourquoi-ameliorer-sa-cote-de-credit/',
#  'https://www.s-finance.fr/le-credit-urgent-quel-est-lessentiel-a-savoir-sur-cette-solution-de-pret/',
#  'https://www.s-finance.fr/reglez-vos-problemes-de-dettes-avec-le-rachat-de-credits/',
#  'https://www.s-finance.fr/est-il-interessant-dinvestir-dans-les-nft/',
#  'https://www.s-finance.fr/entreprise-de-reparation-3-conseils-pour-faire-des-economies/',
#  'https://www.s-finance.fr/limportance-de-se-former-pour-monter-un-dossier-de-financement-solide-lors-de-vos-investissements-immobilier/',
#  'https://www.s-finance.fr/quest-ce-que-le-trading-islamique/',
#  'https://www.s-finance.fr/tout-savoir-sur-les-robots-de-trading/',
#  'https://www.s-finance.fr/quelle-est-la-meilleure-banque-pour-un-pret-automobile/',
#  'https://www.s-finance.fr/donner-pour-mieux-recevoir-la-defiscalisation-par-les-dons-aux-associations/',
#  'https://www.s-finance.fr/5-avantages-de-lutilisation-dun-simulateur-de-pret/',
#  'https://www.s-finance.fr/investir-en-bourse-la-dure-loi-de-lapprentissage-et-de-la-patience/',
#  'https://www.s-finance.fr/le-courtier-en-credit-un-expert-qui-vous-aidera-a-obtenir-un-credit-immobilier/',
#  'https://www.s-finance.fr/trouvez-le-credit-consommation-le-moins-cher/',
#  'https://www.s-finance.fr/quel-type-dor-pouvez-vous-vendre/',
#  'https://www.s-finance.fr/independants-quand-prendre-sa-retraite/',
#  'https://www.s-finance.fr/quels-sont-les-points-forts-de-la-fiat-500/',
#  'https://www.s-finance.fr/quelle-mutuelle-choisir-pour-les-microentrepreneurs/',
#  'https://www.s-finance.fr/comment-defiscaliser-sans-risque/',
#  'https://www.s-finance.fr/quest-ce-que-le-pret-a-temperament/',
#  'https://www.s-finance.fr/une-nouvelle-generation-accro-a-limmobilier-linteret-de-la-scpi/',
#  'https://www.s-finance.fr/comment-fonctionne-la-location-meublee-non-professionnelle/',
#  'https://www.s-finance.fr/pourquoi-faire-appel-a-un-cabinet-comptable/',
#  'https://www.s-finance.fr/assurance-auto-comment-la-choisir-au-meilleur-prix/',
#  'https://www.s-finance.fr/pourquoi-souscrire-une-assurance-auto-au-tiers/',
#  'https://www.s-finance.fr/quels-sont-les-avantages-dune-epargne-plurielle/',
#  'https://www.s-finance.fr/assurance-pour-les-particuliers-conseils-et-comparatifs/',
#  'https://www.s-finance.fr/tout-comprendre-sur-la-tva/',
#  'https://www.s-finance.fr/la-fiscalite-dun-plan-depargne-retraite/',
#  'https://www.s-finance.fr/est-il-possible-dobtenir-un-credit-rapidement/',
#  'https://www.s-finance.fr/quels-sont-les-metiers-populaires-du-monde-de-la-finance/',
#  'https://www.s-finance.fr/actualites-sur-les-taux-de-credits-immobilier-en-2022/',
#  'https://www.s-finance.fr/3eme-pilier-quelles-deductions-fiscales-pour-2022/',
#  'https://www.s-finance.fr/comment-combattre-la-fraude-a-lassurance/',
#  'https://www.s-finance.fr/conseils-pour-investir-dans-limmobilier-neuf/',
#  'https://www.s-finance.fr/notre-avis-sur-les-offres-et-services-de-compte-nickel-2022/',
#  'https://www.s-finance.fr/resilies-le-calvaire-pour-trouver-une-assurance-auto/',
#  'https://www.s-finance.fr/assurances-et-mutuelles-comment-economiser/',
#  'https://www.s-finance.fr/decouvrez-cette-nouvelle-banque-dediee-aux-professionnels/',
#  'https://www.s-finance.fr/comment-obtenir-un-credit-immobilier-en-cdd/',
#  'https://www.s-finance.fr/auto-entrepreneurs-et-chomage-caracteristiques-allocations-et-droits/',
#  'https://www.s-finance.fr/quel-est-linteret-de-mettre-en-place-un-numero-gratuit-pour-son-service-client/',
#  'https://www.s-finance.fr/ne-negligez-pas-les-conseils-pour-la-gestion-de-patrimoine/',
#  'https://www.s-finance.fr/les-avantages-de-la-banque-en-ligne/',
#  'https://www.s-finance.fr/finance-3-idees-de-placement-pour-faire-fructifier-son-argent-en-2022/',
#  'https://www.s-finance.fr/financer-son-entreprise-pourquoi-la-banque-nest-pas-la-solution/',
#  'https://www.s-finance.fr/lessentiel-de-ce-quil-faut-savoir-sur-la-plateforme-binance/',
#  'https://www.s-finance.fr/comment-obtenir-un-meilleur-devis-dassurance-auto/',
#  'https://www.s-finance.fr/utiliser-un-simulateur-pour-trouver-la-meilleure-offre-de-credit-en-ligne/',
#  'https://www.s-finance.fr/assurance-vie-pourquoi/',
#  'https://www.s-finance.fr/maximalisme-ou-pluralisme-le-bitcoin-pour-les-gouverner-tous/',
#  'https://www.s-finance.fr/que-devez-vous-considerer-lorsque-vous-souscrivez-une-assurance/',
#  'https://www.s-finance.fr/quels-sont-les-avantages-a-choisir-une-banque-en-ligne/',
#  'https://www.s-finance.fr/quelles-sont-les-aides-proposees-aux-entreprises/',
#  'https://www.s-finance.fr/comment-reduire-ses-depenses-electriques-dans-le-menage/',
#  'https://www.s-finance.fr/credits-a-la-consommation-en-ligne-les-avantages/',
#  'https://www.s-finance.fr/comment-renegocier-pret-immobilier-avec-sa-banque/',
#  'https://www.s-finance.fr/acheter-un-bien-immobilier-en-espagne-pourquoi-opter-pour-une-agence-specialisee/',
#  'https://www.s-finance.fr/beneficier-des-meilleurs-forfaits-pour-les-lunettes-et-les-dents-de-votre-enfant/',
#  'https://www.s-finance.fr/comment-defiscaliser-en-2021/',
#  'https://www.s-finance.fr/comment-calculer-le-cout-de-revient-dun-chantier/',
#  'https://www.s-finance.fr/des-conseils-pour-profiter-au-mieux-de-la-loi-pinel/',
#  'https://www.s-finance.fr/qui-peut-etre-remunere-en-cesu/',
#  'https://www.s-finance.fr/quels-sont-les-risques-environnementaux/',
#  'https://www.s-finance.fr/quels-sont-les-meilleurs-placements-sans-risques/',
#  'https://www.s-finance.fr/quelle-est-la-base-de-remboursement-de-la-securite-sociale-pour-les-lunettes/',
#  'https://www.s-finance.fr/quel-est-le-role-de-la-bourse/',
#  'https://www.s-finance.fr/quest-ce-quun-domicile-volontaire/',
#  'https://www.s-finance.fr/pourquoi-faire-une-declaration-daccident-scolaire/',
#  'https://www.s-finance.fr/pourquoi-faire-appel-a-un-fond-dinvestissement/',
#  'https://www.s-finance.fr/est-ce-que-le-ripple-va-monter/',
#  'https://www.s-finance.fr/comment-trouver-100-000-euros/',
#  'https://www.s-finance.fr/comment-rectifier-une-declaration-dimpot/',
#  'https://www.s-finance.fr/comment-partir-de-zero-et-devenir-riche/',
#  'https://www.s-finance.fr/comment-payer-avec-du-bitcoin/',
#  'https://www.s-finance.fr/comment-miner-le-litecoin/',
#  'https://www.s-finance.fr/comment-obtenir-le-diplome-dauxiliaire-de-vie/',
#  'https://www.s-finance.fr/comment-investir-dans-des-sicav/',
#  'https://www.s-finance.fr/comment-jeff-bezos-a-commence/',
#  'https://www.s-finance.fr/comment-investir-a-moindre-cout/',
#  'https://www.s-finance.fr/comment-fonctionne-la-garantie-decennale/',
#  'https://www.s-finance.fr/comment-faire-passer-une-residence-secondaire-en-residence-principale/',
#  'https://www.s-finance.fr/comment-telecharger-metatrader-4/',
#  'https://www.s-finance.fr/comment-eviter-la-crise-economique/',
#  'https://www.s-finance.fr/comment-devenir-riche-avec-le-dropshipping/',
#  'https://www.s-finance.fr/comment-declarer-une-personne-a-lurssaf/',
#  'https://www.s-finance.fr/comment-creer-un-financement-participatif/',
#  'https://www.s-finance.fr/comment-consulter-ses-impots-en-ligne/',
#  'https://www.s-finance.fr/comment-developper-une-strategie-de-trading/',
#  'https://www.s-finance.fr/comment-apprendre-a-negocier-du-forex/',
#  'https://www.s-finance.fr/cest-quoi-les-fonds-en-euros/',
#  'https://www.s-finance.fr/chefs-dentreprise-pourquoi-contacter-ce-cabinet-de-courtage-en-placements-de-tresorerie/',
#  'https://www.s-finance.fr/se-renseigner-sur-les-cryptomonnaies-avant-dinvestir-des-economies/',
#  'https://www.s-finance.fr/ce-quil-faut-savoir-sur-role-de-lexpert-comptable/',
#  'https://www.s-finance.fr/comment-reduire-ses-impots-en-2018/']

# %% [markdown]
# ### Récupérer les infos qu'on souhaite sur chaque article

# %%
def get_article_info(r, url_article):
    # Liste de variables
    noms_variables = [
        'url',  # URL scrapée
        'canonical_url', 'slug', 'meta_title', 'meta_desc',  # Infos issues de la balise meta
        'date_published', 'date_modified',  # Infos dates
        'author',  # Parfois en meta
        'title', 'category', 'views', 'reading_time',  # Metadonnées contenues ailleurs que dans la balise meta
        'content', 'raw_content'  # Contenu de la page
    ]
    
    # Initialisation du dictionnaire
    data = {nom: np.nan for nom in noms_variables}
    
    data['url'] = url_article
    
    soup = BeautifulSoup(r.content, 'lxml')
    
    try:
        data['canonical_url'] = soup.find('link', {'rel': 'canonical'})['href']
    except:
        pass
    
    try:
        data['slug'] = data['canonical_url'].split('/')[-2] if data['canonical_url'] else np.nan
    except:
        pass

    try:
        data['meta_title'] = soup.find('meta', {'property': 'og:title'})['content']
    except:
        pass

    try:
        data['meta_desc'] = soup.find('meta', {'property': 'og:description'})['content']
    except:
        pass

    try:
        data['date_published'] = pd.to_datetime(soup.find('meta', {'property': 'article:published_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['date_modified'] = pd.to_datetime(soup.find('meta', {'property': 'article:modified_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['author'] = soup.find("meta", {'name': 'author'})['content']
    except:
        try:
            data['author'] = soup.find(class_="author").text.split('Publié par ')[-1]
        except:
            pass

    try:
        data['title'] = soup.find('h1').text
    except:
        pass

    try:
        data['category'] = [x.text for x in soup.find_all(class_="tdb-entry-category")]
    except:
        pass

    try:
        data['views'] = int(soup.find('div', class_=lambda x: x and x.startswith('views')).text)
    except:
        pass

    try:
        data['reading_time'] = int(soup.find('meta', {'name': 'twitter:data2'})['content'].split(' ')[0]) if soup.find('meta', {'name': 'twitter:data2'}) and 'minutes' in soup.find('meta', {'name': 'twitter:data2'})['content'] else np.nan
    except:
        pass

    try:
        data['content'] = BeautifulSoup(str(soup.find("div", class_="td-post-content")), 'lxml').get_text()
    except:
        pass

    try:
        data['raw_content'] = str(soup.find("div", class_="td-post-content"))
    except:
        pass

    # Ajout de features
    data['length'] = len(str(data['content']).split())
    
    if pd.notnull(data['date_published']):
        data['days_since_published'] = int((pd.Timestamp.now(tz='UTC') - data['date_published']).days)
    else:
        data['days_since_published'] = np.nan
    
    # Création de la série
    series = pd.Series(data)
    series.name = url_article
    
    # Ajout de features supplémentaires
    if pd.notnull(data.get('views')) and pd.notnull(data.get('days_since_published')):
        series['views_daily'] = series['views'] / (1+series['days_since_published'])
        series['views_monthly'] = series['views_daily'] * 30
    else:
        series['views_daily'] = np.nan
        series['views_monthly'] = np.nan
    
    series['website'] = top_url
    
    return series

# %% [markdown]
# ## Fonction finale

# %%
article_list = get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
# 100%|██████████| 17/17 [00:09<00:00,  1.84it/s]

# %% [markdown]
# ### Fonction finale

# %%
# Import des packages
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Initialisation du compteur
start_time = time.time()

# Fonction principale qui sauvegarde le DataFrame dans un fichier CSV et le retourne
def scrape_all_articles(urls, batch_size=250, max_workers=20):
    # Initialisation d'une session réutilisable
    session = rq.Session()

    # Création d'une fonction qui traite chaque URL
    def process_url(url):
            try:
                r = session.get(url)
                return get_article_info(r, url)
            except Exception as e:
                print(f"Erreur pour {url}: {str(e)}")
                return pd.Series(name=url)

    # Utilise ThreadPoolExecutor pour paralléliser le traitement
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Parcourt la liste d'URLs par lots de taille 'batch_size'
        for i in range(0, len(urls), batch_size):
            # Extrait un lot d'URLs
            batch = urls[i:i+batch_size]
            # Crée et soumet des tâches pour chaque URL du lot
            futures = [executor.submit(process_url, url) for url in batch]
            
            # Traite les résultats au fur et à mesure qu'ils sont terminés
            for future in tqdm(as_completed(futures), total=len(batch), desc=f"Batch {i//batch_size + 1} / {len(urls)//batch_size+1}"):
                # Récupère le résultat de la tâche
                result = future.result()
                # Si le résultat n'est pas None (pas d'erreur), l'ajoute aux résultats
                if result is not None:
                    results.append(result)
    
    # Création du DataFrame final
    df_final = pd.DataFrame(results)
    
    # Ajout de colonnes calculées
    df_final['website'] = top_url
    df_final['scraping_date'] = pd.Timestamp.now(tz='UTC')

    df_final.columns = ['article_url', 'article_canonical_url', 'article_slug',
       'article_meta_title', 'article_meta_desc', 'article_date_published',
       'article_date_modified', 'article_author', 'article_title',
       'article_category', 'article_views', 'article_reading_time',
       'article_content', 'article_raw_content', 'article_length',
       'days_since_published', 'article_views_daily', 'article_views_monthly',
       'website', 'scraping_date']

    # Sauvegarde en CSV
    df_final.to_csv(f'scraping_{abbr}.csv', sep='|', index=True)
    print(f"Scraping terminé. Total d'articles : {len(df_final)}")
    return df_final

df = scrape_all_articles(article_list)

end_time = time.time()
print(end_time - start_time)
# Out:
# Batch 1 / 4: 100%|██████████| 250/250 [00:33<00:00,  7.46it/s]
# Batch 2 / 4:  70%|███████   | 175/250 [00:23<00:08,  8.36it/s]

# %%
# Création d'un rapport de profil avec pandas_profiling
profile = ProfileReport(df, title=f"{abbr.title()} Scraping Report", explorative=True)

# Génération du rapport au format HTML
profile.to_file(f"scraping_report_{abbr}.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\MSI\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
